# %%
# !pip install git+git://github.com/geopandas/geopandas.git --quiet
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from citipy) (0.16)

# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
import numpy as np
# to get a list of random longitudes and latitudes
# import geopy
# from geopy.geocoders import Nominatim
# from geopy.extra.rate_limiter import RateLimiter

from config import api_key
from random import uniform

# to find a city based on longitude and latitude
from citipy import citipy

# %%
# x, y = uniform(-180,180), uniform(-90, 90)

# def newpoint():
#    return uniform(-180,180), uniform(-90, 90)

# the_points = (newpoint() for x in range(15))
# for points in the_points:
# #    print(point)

# %%
# Create a set of random lat and lng combinations
lat_lngs =[]
lats = np.random.uniform(low=-90.000, high=90.000, size=1300)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1300)
lat_lngs = zip(lats, lngs)
# print(*lat_lngs)

# %%
# create a list to hold the cities
cities =[]

# Identify nearest city for each lat, lng combination
# for point in points:
#     city = citipy.nearest_city(point[0], point[1]).city_name
    
for points in lat_lngs:
    city = citipy.nearest_city(points[0], points[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
#     print(cities) 
# check the city count to make sure we have at least 500
len(cities)
#print(cities)
# Out:
# 559

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="
query_url

# set up lists to hold reponse info and city counter
city_weather = []
city_cnt = 1

print(f"There are {len(cities)}")
for city in cities:
    print(f"City number {city_cnt} is {city}")
    try:
        response = requests.get(query_url + city).json()
        city_lat = response['coord']['lat']
        city_mtemp = response['main']['temp_max']
        city_humidity = response['main']['humidity']
        city_cloudiness = response['clouds']['all']
        city_wspeed = response['wind']['speed']
        city_weather.append({"city":city,
                      "Latitude":city_lat,
                      "Max Temp":city_mtemp,
                      "Humidity":city_humidity,
                      "Cloudiness":city_cloudiness,
                      "Wind Speed":city_wspeed,
                      })
        print(f"{city} processed successfully")
        city_cnt +=1
        
    except KeyError:
        print(f'No data for {city}. Skipping {city}')
        city_cnt +=1
# Out:
# There are 559
# City number 1 is jamestown
# jamestown processed successfully
# City number 2 is port elizabeth
# port elizabeth processed successfully
# City number 3 is kuytun
# kuytun processed successfully
# City number 4 is punta arenas
# punta arenas processed successfully
# City number 5 is albany
# albany processed successfully
# City number 6 is kaeo
# kaeo processed successfully
# City number 7 is kaitangata
# kaitangata processed successfully
# City number 8 is victoria
# victoria processed successfully
# City number 9 is palabuhanratu
# No data for palabuhanratu. Skipping palabuhanratu
# City number 10 is jalor
# jalor processed successfully
# City number 11 is fort nelson
# fort nelson processed successfully
# City number 12 is souillac
# souillac processed successfully
# City number 13 is castro
# castro processed successfully
# City number 14 is vardo
# vardo processed successfully
# City number 15 is ushuaia
# ushuaia processed successfully
# City number 16 is iquitos
# iquitos processed successfully
# City number 17 is sicuani
# sicuani processed successfully
# City number 18 is hilo
# hilo processed successfully
# City number 19 is butaritari
# butaritari processed successfully
# City number 20 is thompson
# thompson processed successfully
# City number 21 is pevek
# pevek processed successfully
# City number 22 is busselton
# busselton processed successfully
# City number 23 is barentsburg
# No data for barentsburg. Skipping barentsburg
# City number 24 is san pedro
# san pedro processed successfully
# City number 25 is rikitea
# rikitea processed successfully
# City number 26 is buraydah
# buraydah processed successfully
# City number 27 is anadyr
# anadyr processed successfully
# City number 28 is lebu
# lebu processed successfully
# City number 29 is viking
# viking processed successfully
# City number 30 is villalba
# villalba processed successfully
# City number 31 is tessalit
# tessalit processed successfully
# City number 32 is arraial do cabo
# arraial do cabo processed successfully
# City number 33 is chuy
# chuy processed successfully
# City number 34 is kirishi
# kirishi processed successfully
# City number 35 is yenangyaung
# yenangyaung processed successfully
# City number 36 is klaksvik
# klaksvik processed successfully
# City number 37 is dunedin
# dunedin processed successfully
# City number 38 is alyangula
# alyangula processed successfully
# City number 39 is biak
# biak processed successfully
# City number 40 is benguela
# benguela processed successfully
# City number 41 is poum
# poum processed successfully
# City number 42 is bethel
# bethel processed successfully
# City number 43 is port alfred
# port alfred processed successfully
# City number 44 is madinat sittah uktubar
# madinat sittah uktubar processed successfully
# City number 45 is yerbogachen
# yerbogachen processed successfully
# City number 46 is new norfolk
# new norfolk processed successfully
# City number 47 is tome-acu
# No data for tome-acu. Skipping tome-acu
# City number 48 is bredasdorp
# bredasdorp processed successfully
# City number 49 is aksarka
# aksarka processed successfully
# City number 50 is mataura
# mataura processed successfully
# City number 51 is jiuquan
# jiuquan processed successfully
# City number 52 is dalbandin
# dalbandin processed successfully
# City number 53 is vanimo
# vanimo processed successfully
# City number 54 is bonfim
# bonfim processed successfully
# City number 55 is hobart
# hobart processed successfully
# City number 56 is tsihombe
# No data for tsihombe. Skipping tsihombe
# City number 57 is sentyabrskiy
# No data for sentyabrskiy. Skipping sentyabrskiy
# City number 58 is hermanus
# hermanus processed successfully
# City number 59 is penzance
# penzance processed successfully
# City number 60 is torbay
# torbay processed successfully
# City number 61 is vaini
# vaini processed successfully
# City number 62 is solovetskiy
# No data for solovetskiy. Skipping solovetskiy
# City number 63 is newark
# newark processed successfully
# City number 64 is pointe michel
# pointe michel processed successfully
# City number 65 is kampot
# kampot processed successfully
# City number 66 is dubbo
# dubbo processed successfully
# City number 67 is aksu
# aksu processed successfully
# City number 68 is la ronge
# la ronge processed successfully
# City number 69 is kruisfontein
# kruisfontein processed successfully
# City number 70 is sanger
# sanger processed successfully
# City number 71 is ribeira grande
# ribeira grande processed successfully
# City number 72 is bluff
# bluff processed successfully
# City number 73 is east london
# east london processed successfully
# City number 74 is yulara
# yulara processed successfully
# City number 75 is cidreira
# cidreira processed successfully
# City number 76 is karpathos
# karpathos processed successfully
# City number 77 is namibe
# namibe processed successfully
# City number 78 is atuona
# atuona processed successfully
# City number 79 is almaznyy
# almaznyy processed successfully
# City number 80 is faanui
# faanui processed successfully
# City number 81 is puerto ayora
# puerto ayora processed successfully
# City number 82 is atar
# atar processed successfully
# City number 83 is riachao das neves
# riachao das neves processed successfully
# City number 84 is belushya guba
# No data for belushya guba. Skipping belushya guba
# City number 85 is codrington
# codrington processed successfully
# City number 86 is saskylakh
# saskylakh processed successfully
# City number 87 is tevaitoa
# tevaitoa processed successfully
# City number 88 is cabedelo
# cabedelo processed successfully
# City number 89 is marawi
# marawi processed successfully
# City number 90 is ulaangom
# ulaangom processed successfully
# City number 91 is povenets
# povenets processed successfully
# City number 92 is hirado
# hirado processed successfully
# City number 93 is saint-philippe
# saint-philippe processed successfully
# City number 94 is limbang
# limbang processed successfully
# City number 95 is amderma
# No data for amderma. Skipping amderma
# City number 96 is tiksi
# tiksi processed successfully
# City number 97 is khatanga
# khatanga processed successfully
# City number 98 is avarua
# avarua processed successfully
# City number 99 is sarangani
# sarangani processed successfully
# City number 100 is taoudenni
# taoudenni processed successfully
# City number 101 is chapais
# chapais processed successfully
# City number 102 is sao filipe
# sao filipe processed successfully
# City number 103 is yar-sale
# yar-sale processed successfully
# City number 104 is qaanaaq
# qaanaaq processed successfully
# City number 105 is mar del plata
# mar del plata processed successfully
# City number 106 is terrak
# terrak processed successfully
# City number 107 is provideniya
# provideniya processed successfully
# City number 108 is attawapiskat
# No data for attawapiskat. Skipping attawapiskat
# City number 109 is grindavik
# grindavik processed successfully
# City number 110 is ancud
# ancud processed successfully
# City number 111 is raychikhinsk
# raychikhinsk processed successfully
# City number 112 is saint george
# saint george processed successfully
# City number 113 is tasiilaq
# tasiilaq processed successfully
# City number 114 is aranos
# aranos processed successfully
# City number 115 is buala
# buala processed successfully
# City number 116 is kapaa
# kapaa processed successfully
# City number 117 is illoqqortoormiut
# No data for illoqqortoormiut. Skipping illoqqortoormiut
# City number 118 is cape town
# cape town processed successfully
# City number 119 is sao joao da barra
# sao joao da barra processed successfully
# City number 120 is taolanaro
# No data for taolanaro. Skipping taolanaro
# City number 121 is tuktoyaktuk
# tuktoyaktuk processed successfully
# City number 122 is shimoda
# shimoda processed successfully
# City number 123 is srednekolymsk
# srednekolymsk processed successfully
# City number 124 is wairoa
# wairoa processed successfully
# City number 125 is great falls
# great falls processed successfully
# City number 126 is providencia
# providencia processed successfully
# City number 127 is toliary
# No data for toliary. Skipping toliary
# City number 128 is yellowknife
# yellowknife processed successfully
# City number 129 is naze
# naze processed successfully
# City number 130 is esperance
# esperance processed successfully
# City number 131 is kigali
# kigali processed successfully
# City number 132 is guarapari
# guarapari processed successfully
# City number 133 is geraldton
# geraldton processed successfully
# City number 134 is almeirim
# almeirim processed successfully
# City number 135 is port macquarie
# port macquarie processed successfully
# City number 136 is petropavlovsk-kamchatskiy
# petropavlovsk-kamchatskiy processed successfully
# City number 137 is hovd
# hovd processed successfully
# City number 138 is lorengau
# lorengau processed successfully
# City number 139 is vestmannaeyjar
# vestmannaeyjar processed successfully
# City number 140 is port maria
# port maria processed successfully
# City number 141 is rocha
# rocha processed successfully
# City number 142 is ibra
# ibra processed successfully
# City number 143 is puerto rico
# puerto rico processed successfully
# City number 144 is san patricio
# san patricio processed successfully
# City number 145 is honiara
# honiara processed successfully
# City number 146 is barrow
# barrow processed successfully
# City number 147 is scarborough
# scarborough processed successfully
# City number 148 is taraza
# taraza processed successfully
# City number 149 is loubomo
# loubomo processed successfully
# City number 150 is leesburg
# leesburg processed successfully
# City number 151 is tuy hoa
# tuy hoa processed successfully
# City number 152 is deputatskiy
# deputatskiy processed successfully
# City number 153 is hithadhoo
# hithadhoo processed successfully
# City number 154 is qurbus
# qurbus processed successfully
# City number 155 is karaton
# karaton processed successfully
# City number 156 is udachnyy
# udachnyy processed successfully
# City number 157 is flin flon
# flin flon processed successfully
# City number 158 is mount gambier
# mount gambier processed successfully
# City number 159 is tuatapere
# tuatapere processed successfully
# City number 160 is ardmore
# ardmore processed successfully
# City number 161 is dingle
# dingle processed successfully
# City number 162 is berlevag
# berlevag processed successfully
# City number 163 is vila franca do campo
# vila franca do campo processed successfully
# City number 164 is luchegorsk
# luchegorsk processed successfully
# City number 165 is casper
# casper processed successfully
# City number 166 is karratha
# karratha processed successfully
# City number 167 is egvekinot
# egvekinot processed successfully
# City number 168 is campo maior
# campo maior processed successfully
# City number 169 is kupang
# kupang processed successfully
# City number 170 is sao miguel
# sao miguel processed successfully
# City number 171 is arona
# arona processed successfully
# City number 172 is thetford mines
# thetford mines processed successfully
# City number 173 is varnavino
# varnavino processed successfully
# City number 174 is myanaung
# myanaung processed successfully
# City number 175 is labuan
# labuan processed successfully
# City number 176 is katsuura
# katsuura processed successfully
# City number 177 is santiago del estero
# santiago del estero processed successfully
# City number 178 is pingxiang
# pingxiang processed successfully
# City number 179 is cherskiy
# cherskiy processed successfully
# City number 180 is alice springs
# alice springs processed successfully
# City number 181 is krasnoselkup
# krasnoselkup processed successfully
# City number 182 is kodiak
# kodiak processed successfully
# City number 183 is lithgow
# lithgow processed successfully
# City number 184 is burns lake
# burns lake processed successfully
# City number 185 is saint-joseph
# saint-joseph processed successfully
# City number 186 is bagan
# bagan processed successfully
# City number 187 is peniche
# peniche processed successfully
# City number 188 is atchison
# atchison processed successfully
# City number 189 is khani
# khani processed successfully
# City number 190 is moskovskiy
# moskovskiy processed successfully
# City number 191 is satitoa
# No data for satitoa. Skipping satitoa
# City number 192 is half moon bay
# half moon bay processed successfully
# City number 193 is broome
# broome processed successfully
# City number 194 is faya
# faya processed successfully
# City number 195 is nampa
# nampa processed successfully
# City number 196 is sovetskiy
# sovetskiy processed successfully
# City number 197 is hasaki
# hasaki processed successfully
# City number 198 is axim
# axim processed successfully
# City number 199 is bonavista
# bonavista processed successfully
# City number 200 is mogadishu
# mogadishu processed successfully
# City number 201 is puerto escondido
# puerto escondido processed successfully
# City number 202 is mys shmidta
# No data for mys shmidta. Skipping mys shmidta
# City number 203 is louisbourg
# No data for louisbourg. Skipping louisbourg
# City number 204 is ponta do sol
# ponta do sol processed successfully
# City number 205 is harper
# harper processed successfully
# City number 206 is luganville
# luganville processed successfully
# City number 207 is nizhneyansk
# No data for nizhneyansk. Skipping nizhneyansk
# City number 208 is fairbanks
# fairbanks processed successfully
# City number 209 is nanortalik
# nanortalik processed successfully
# City number 210 is longyearbyen
# longyearbyen processed successfully
# City number 211 is marcona
# No data for marcona. Skipping marcona
# City number 212 is presidencia roque saenz pena
# presidencia roque saenz pena processed successfully
# City number 213 is dikson
# dikson processed successfully
# City number 214 is sainte-anne-des-monts
# sainte-anne-des-monts processed successfully
# City number 215 is saurimo
# saurimo processed successfully
# City number 216 is sitka
# sitka processed successfully
# City number 217 is necochea
# necochea processed successfully
# City number 218 is vaitupu
# No data for vaitupu. Skipping vaitupu
# City number 219 is calabozo
# calabozo processed successfully
# City number 220 is lobito
# lobito processed successfully
# City number 221 is rorvik
# rorvik processed successfully
# City number 222 is aitape
# aitape processed successfully
# City number 223 is stornoway
# stornoway processed successfully
# City number 224 is maramba
# maramba processed successfully
# City number 225 is upernavik
# upernavik processed successfully
# City number 226 is brigantine
# brigantine processed successfully
# City number 227 is port keats
# port keats processed successfully
# City number 228 is nouakchott
# nouakchott processed successfully
# City number 229 is elban
# elban processed successfully
# City number 230 is aklavik
# aklavik processed successfully
# City number 231 is safwah
# No data for safwah. Skipping safwah
# City number 232 is lolua
# No data for lolua. Skipping lolua
# City number 233 is palmer
# palmer processed successfully
# City number 234 is jijiga
# jijiga processed successfully
# City number 235 is cermik
# cermik processed successfully
# City number 236 is mount isa
# mount isa processed successfully
# City number 237 is palmares
# palmares processed successfully
# City number 238 is grand river south east
# No data for grand river south east. Skipping grand river south east
# City number 239 is georgetown
# georgetown processed successfully
# City number 240 is carnarvon
# carnarvon processed successfully
# City number 241 is bairiki
# bairiki processed successfully
# City number 242 is majene
# majene processed successfully
# City number 243 is ho
# No data for ho. Skipping ho
# City number 244 is troitskoye
# troitskoye processed successfully
# City number 245 is fortuna
# fortuna processed successfully
# City number 246 is puerto colombia
# puerto colombia processed successfully
# City number 247 is morondava
# morondava processed successfully
# City number 248 is richards bay
# richards bay processed successfully
# City number 249 is muros
# muros processed successfully
# City number 250 is tahe
# tahe processed successfully
# City number 251 is mahebourg
# mahebourg processed successfully
# City number 252 is redding
# redding processed successfully
# City number 253 is yenagoa
# yenagoa processed successfully
# City number 254 is lushunkou
# No data for lushunkou. Skipping lushunkou
# City number 255 is belen
# belen processed successfully
# City number 256 is vila velha
# vila velha processed successfully
# City number 257 is pierre
# pierre processed successfully
# City number 258 is shahrud
# shahrud processed successfully
# City number 259 is sur
# sur processed successfully
# City number 260 is port lincoln
# port lincoln processed successfully
# City number 261 is paita
# paita processed successfully
# City number 262 is agadez
# agadez processed successfully
# City number 263 is sokoni
# sokoni processed successfully
# City number 264 is conakry
# conakry processed successfully
# City number 265 is carballo
# carballo processed successfully
# City number 266 is imeni zhelyabova
# imeni zhelyabova processed successfully
# City number 267 is chapada dos guimaraes
# chapada dos guimaraes processed successfully
# City number 268 is skalistyy
# No data for skalistyy. Skipping skalistyy
# City number 269 is alta floresta
# alta floresta processed successfully
# City number 270 is oudtshoorn
# oudtshoorn processed successfully
# City number 271 is manzanillo
# manzanillo processed successfully
# City number 272 is mugla
# mugla processed successfully
# City number 273 is zhanatas
# No data for zhanatas. Skipping zhanatas
# City number 274 is adiake
# adiake processed successfully
# City number 275 is klyuchi
# klyuchi processed successfully
# City number 276 is port moresby
# port moresby processed successfully
# City number 277 is bukama
# bukama processed successfully
# City number 278 is neman
# neman processed successfully
# City number 279 is baykit
# baykit processed successfully
# City number 280 is chokurdakh
# chokurdakh processed successfully
# City number 281 is pokoynoye
# pokoynoye processed successfully
# City number 282 is moron
# moron processed successfully
# City number 283 is sorland
# sorland processed successfully
# City number 284 is karlivka
# karlivka processed successfully
# City number 285 is witu
# witu processed successfully
# City number 286 is villa union
# villa union processed successfully
# City number 287 is muroto
# muroto processed successfully
# City number 288 is kelowna
# kelowna processed successfully
# City number 289 is vaxjo
# vaxjo processed successfully
# City number 290 is novo aripuana
# novo aripuana processed successfully
# City number 291 is jackson
# jackson processed successfully
# City number 292 is valer
# valer processed successfully
# City number 293 is safford
# safford processed successfully
# City number 294 is ornskoldsvik
# ornskoldsvik processed successfully
# City number 295 is beloha
# beloha processed successfully
# City number 296 is nuevo progreso
# nuevo progreso processed successfully
# City number 297 is bosaso
# bosaso processed successfully
# City number 298 is ponta delgada
# ponta delgada processed successfully
# City number 299 is jambi
# jambi processed successfully
# City number 300 is comodoro rivadavia
# comodoro rivadavia processed successfully
# City number 301 is panaba
# panaba processed successfully
# City number 302 is susuman
# susuman processed successfully
# City number 303 is gigmoto
# gigmoto processed successfully
# City number 304 is oranjemund
# oranjemund processed successfully
# City number 305 is cayenne
# cayenne processed successfully
# City number 306 is tostamaa
# No data for tostamaa. Skipping tostamaa
# City number 307 is husavik
# husavik processed successfully
# City number 308 is camopi
# camopi processed successfully
# City number 309 is antofagasta
# antofagasta processed successfully
# City number 310 is remanso
# remanso processed successfully
# City number 311 is boyolangu
# boyolangu processed successfully
# City number 312 is verkhnetulomskiy
# verkhnetulomskiy processed successfully
# City number 313 is norman wells
# norman wells processed successfully
# City number 314 is leningradskiy
# leningradskiy processed successfully
# City number 315 is micheweni
# micheweni processed successfully
# City number 316 is sardinia
# sardinia processed successfully
# City number 317 is kununurra
# kununurra processed successfully
# City number 318 is sena madureira
# sena madureira processed successfully
# City number 319 is novobirilyussy
# novobirilyussy processed successfully
# City number 320 is warqla
# No data for warqla. Skipping warqla
# City number 321 is okhotsk
# okhotsk processed successfully
# City number 322 is mantua
# mantua processed successfully
# City number 323 is molochnoye
# molochnoye processed successfully
# City number 324 is macaboboni
# No data for macaboboni. Skipping macaboboni
# City number 325 is sao jose da coroa grande
# sao jose da coroa grande processed successfully
# City number 326 is clyde river
# clyde river processed successfully
# City number 327 is tolentino
# tolentino processed successfully
# City number 328 is coquimbo
# coquimbo processed successfully
# City number 329 is vilyuysk
# vilyuysk processed successfully
# City number 330 is otradinskiy
# No data for otradinskiy. Skipping otradinskiy
# City number 331 is san isidro
# san isidro processed successfully
# City number 332 is northam
# northam processed successfully
# City number 333 is senneterre
# senneterre processed successfully
# City number 334 is thatta
# thatta processed successfully
# City number 335 is cabo san lucas
# cabo san lucas processed successfully
# City number 336 is lagoa
# lagoa processed successfully
# City number 337 is port shepstone
# port shepstone processed successfully
# City number 338 is montrose
# montrose processed successfully
# City number 339 is vanavara
# vanavara processed successfully
# City number 340 is ballina
# ballina processed successfully
# City number 341 is khandyga
# khandyga processed successfully
# City number 342 is beringovskiy
# beringovskiy processed successfully
# City number 343 is ambovombe
# ambovombe processed successfully
# City number 344 is farafangana
# farafangana processed successfully
# City number 345 is kamaishi
# kamaishi processed successfully
# City number 346 is castelfranco veneto
# castelfranco veneto processed successfully
# City number 347 is devils lake
# devils lake processed successfully
# City number 348 is hambantota
# hambantota processed successfully
# City number 349 is vila
# vila processed successfully
# City number 350 is ambilobe
# ambilobe processed successfully
# City number 351 is mago
# mago processed successfully
# City number 352 is bengkulu
# bengkulu processed successfully
# City number 353 is sisophon
# sisophon processed successfully
# City number 354 is tabas
# tabas processed successfully
# City number 355 is tra vinh
# tra vinh processed successfully
# City number 356 is lavrentiya
# lavrentiya processed successfully
# City number 357 is avera
# avera processed successfully
# City number 358 is tumannyy
# No data for tumannyy. Skipping tumannyy
# City number 359 is soyaux
# soyaux processed successfully
# City number 360 is bargal
# No data for bargal. Skipping bargal
# City number 361 is port augusta
# port augusta processed successfully
# City number 362 is slavyanka
# slavyanka processed successfully
# City number 363 is bambous virieux
# bambous virieux processed successfully
# City number 364 is ahipara
# ahipara processed successfully
# City number 365 is port-gentil
# port-gentil processed successfully
# City number 366 is jiroft
# No data for jiroft. Skipping jiroft
# City number 367 is buluang
# buluang processed successfully
# City number 368 is najran
# najran processed successfully
# City number 369 is stoyba
# No data for stoyba. Skipping stoyba
# City number 370 is sabha
# sabha processed successfully
# City number 371 is douglas
# douglas processed successfully
# City number 372 is severo-kurilsk
# severo-kurilsk processed successfully
# City number 373 is hirara
# hirara processed successfully
# City number 374 is barcelona
# barcelona processed successfully
# City number 375 is linjiang
# linjiang processed successfully
# City number 376 is formoso do araguaia
# No data for formoso do araguaia. Skipping formoso do araguaia
# City number 377 is lethem
# lethem processed successfully
# City number 378 is itarema
# itarema processed successfully
# City number 379 is altay
# altay processed successfully
# City number 380 is bathsheba
# bathsheba processed successfully
# City number 381 is buon me thuot
# No data for buon me thuot. Skipping buon me thuot
# City number 382 is elko
# elko processed successfully
# City number 383 is ternate
# ternate processed successfully
# City number 384 is rudsar
# rudsar processed successfully
# City number 385 is innisfail
# innisfail processed successfully
# City number 386 is meulaboh
# meulaboh processed successfully
# City number 387 is aswan
# aswan processed successfully
# City number 388 is guadalupe victoria
# guadalupe victoria processed successfully
# City number 389 is eyl
# eyl processed successfully
# City number 390 is rapid valley
# rapid valley processed successfully
# City number 391 is manavgat
# manavgat processed successfully
# City number 392 is pacific grove
# pacific grove processed successfully
# City number 393 is grootfontein
# grootfontein processed successfully
# City number 394 is tucupita
# tucupita processed successfully
# City number 395 is kontagora
# kontagora processed successfully
# City number 396 is bolungarvik
# No data for bolungarvik. Skipping bolungarvik
# City number 397 is isangel
# isangel processed successfully
# City number 398 is paradwip
# No data for paradwip. Skipping paradwip
# City number 399 is sola
# sola processed successfully
# City number 400 is tornio
# tornio processed successfully
# City number 401 is boysun
# boysun processed successfully
# City number 402 is laguna
# laguna processed successfully
# City number 403 is metro
# metro processed successfully
# City number 404 is verkh-chebula
# verkh-chebula processed successfully
# City number 405 is hamilton
# hamilton processed successfully
# City number 406 is pangnirtung
# pangnirtung processed successfully
# City number 407 is baculin
# baculin processed successfully
# City number 408 is ca mau
# ca mau processed successfully
# City number 409 is yeppoon
# yeppoon processed successfully
# City number 410 is kahului
# kahului processed successfully
# City number 411 is high level
# high level processed successfully
# City number 412 is kapuskasing
# kapuskasing processed successfully
# City number 413 is umzimvubu
# No data for umzimvubu. Skipping umzimvubu
# City number 414 is lompoc
# lompoc processed successfully
# City number 415 is ambo
# ambo processed successfully
# City number 416 is mezhdurechenskiy
# mezhdurechenskiy processed successfully
# City number 417 is dire
# dire processed successfully
# City number 418 is tawkar
# No data for tawkar. Skipping tawkar
# City number 419 is gazanjyk
# gazanjyk processed successfully
# City number 420 is labytnangi
# labytnangi processed successfully
# City number 421 is kokkola
# kokkola processed successfully
# City number 422 is tautira
# tautira processed successfully
# City number 423 is seoul
# seoul processed successfully
# City number 424 is manowa
# manowa processed successfully
# City number 425 is mahadday weyne
# No data for mahadday weyne. Skipping mahadday weyne
# City number 426 is lokosovo
# lokosovo processed successfully
# City number 427 is odweyne
# odweyne processed successfully
# City number 428 is banki
# banki processed successfully
# City number 429 is ivanovka
# ivanovka processed successfully
# City number 430 is iqaluit
# iqaluit processed successfully
# City number 431 is nikolskoye
# nikolskoye processed successfully
# City number 432 is qaqortoq
# qaqortoq processed successfully
# City number 433 is luderitz
# luderitz processed successfully
# City number 434 is los llanos de aridane
# los llanos de aridane processed successfully
# City number 435 is pisco
# pisco processed successfully
# City number 436 is shingu
# shingu processed successfully
# City number 437 is ondorhaan
# No data for ondorhaan. Skipping ondorhaan
# City number 438 is vadso
# vadso processed successfully
# City number 439 is krasnaya polyana
# krasnaya polyana processed successfully
# City number 440 is byron bay
# byron bay processed successfully
# City number 441 is ambon
# ambon processed successfully
# City number 442 is burriana
# burriana processed successfully
# City number 443 is yining
# yining processed successfully
# City number 444 is ossora
# ossora processed successfully
# City number 445 is camacha
# camacha processed successfully
# City number 446 is tecoanapa
# tecoanapa processed successfully
# City number 447 is tual
# tual processed successfully
# City number 448 is marystown
# marystown processed successfully
# City number 449 is koyelga
# koyelga processed successfully
# City number 450 is pedernales
# pedernales processed successfully
# City number 451 is pandan
# pandan processed successfully
# City number 452 is hofn
# hofn processed successfully
# City number 453 is takoradi
# takoradi processed successfully
# City number 454 is sorvag
# No data for sorvag. Skipping sorvag
# City number 455 is ola
# ola processed successfully
# City number 456 is abu dhabi
# abu dhabi processed successfully
# City number 457 is saldanha
# saldanha processed successfully
# City number 458 is caravelas
# caravelas processed successfully
# City number 459 is ilulissat
# ilulissat processed successfully
# City number 460 is kudahuvadhoo
# kudahuvadhoo processed successfully
# City number 461 is burica
# No data for burica. Skipping burica
# City number 462 is kathmandu
# kathmandu processed successfully
# City number 463 is jacareacanga
# jacareacanga processed successfully
# City number 464 is asfi
# asfi processed successfully
# City number 465 is banda aceh
# banda aceh processed successfully
# City number 466 is antalaha
# antalaha processed successfully
# City number 467 is pontianak
# pontianak processed successfully
# City number 468 is oil city
# oil city processed successfully
# City number 469 is menomonie
# menomonie processed successfully
# City number 470 is padang
# padang processed successfully
# City number 471 is peer
# peer processed successfully
# City number 472 is port-cartier
# port-cartier processed successfully
# City number 473 is bontang
# bontang processed successfully
# City number 474 is houma
# houma processed successfully
# City number 475 is juba
# juba processed successfully
# City number 476 is galgani
# No data for galgani. Skipping galgani
# City number 477 is masterton
# masterton processed successfully
# City number 478 is itinga
# itinga processed successfully
# City number 479 is tete
# tete processed successfully
# City number 480 is greenville
# greenville processed successfully
# City number 481 is touros
# touros processed successfully
# City number 482 is okoneshnikovo
# okoneshnikovo processed successfully
# City number 483 is dunmore town
# dunmore town processed successfully
# City number 484 is luanda
# luanda processed successfully
# City number 485 is baijiantan
# baijiantan processed successfully
# City number 486 is zhangjiakou
# zhangjiakou processed successfully
# City number 487 is puerto cabezas
# puerto cabezas processed successfully
# City number 488 is college
# college processed successfully
# City number 489 is andenes
# andenes processed successfully
# City number 490 is thinadhoo
# thinadhoo processed successfully
# City number 491 is haines junction
# haines junction processed successfully
# City number 492 is south lake tahoe
# south lake tahoe processed successfully
# City number 493 is jalu
# jalu processed successfully
# City number 494 is vallenar
# vallenar processed successfully
# City number 495 is port hedland
# port hedland processed successfully
# City number 496 is kutum
# kutum processed successfully
# City number 497 is pinsk
# pinsk processed successfully
# City number 498 is zuwarah
# zuwarah processed successfully
# City number 499 is vao
# vao processed successfully
# City number 500 is hay river
# hay river processed successfully
# City number 501 is tezu
# tezu processed successfully
# City number 502 is tubruq
# No data for tubruq. Skipping tubruq
# City number 503 is komsomolskiy
# komsomolskiy processed successfully
# City number 504 is hami
# hami processed successfully
# City number 505 is shakhovskaya
# shakhovskaya processed successfully
# City number 506 is rudbar
# rudbar processed successfully
# City number 507 is rundu
# rundu processed successfully
# City number 508 is hojai
# hojai processed successfully
# City number 509 is florenville
# florenville processed successfully
# City number 510 is lazaro cardenas
# lazaro cardenas processed successfully
# City number 511 is ketchikan
# ketchikan processed successfully
# City number 512 is olafsvik
# olafsvik processed successfully
# City number 513 is sechura
# sechura processed successfully
# City number 514 is kavieng
# kavieng processed successfully
# City number 515 is margate
# margate processed successfully
# City number 516 is vytegra
# vytegra processed successfully
# City number 517 is xunchang
# xunchang processed successfully
# City number 518 is bereda
# bereda processed successfully
# City number 519 is west hartford
# west hartford processed successfully
# City number 520 is xudat
# xudat processed successfully
# City number 521 is puerto leguizamo
# puerto leguizamo processed successfully
# City number 522 is cap malheureux
# cap malheureux processed successfully
# City number 523 is vicuna
# vicuna processed successfully
# City number 524 is trincomalee
# trincomalee processed successfully
# City number 525 is bandarbeyla
# bandarbeyla processed successfully
# City number 526 is zmievka
# No data for zmievka. Skipping zmievka
# City number 527 is georgiyevka
# georgiyevka processed successfully
# City number 528 is florence
# florence processed successfully
# City number 529 is sooke
# sooke processed successfully
# City number 530 is morehead
# morehead processed successfully
# City number 531 is shanhetun
# shanhetun processed successfully
# City number 532 is cozumel
# cozumel processed successfully
# City number 533 is zaria
# zaria processed successfully
# City number 534 is ghiror
# ghiror processed successfully
# City number 535 is constantine
# constantine processed successfully
# City number 536 is dali
# dali processed successfully
# City number 537 is valleyview
# valleyview processed successfully
# City number 538 is tilichiki
# tilichiki processed successfully
# City number 539 is sembe
# sembe processed successfully
# City number 540 is meschede
# meschede processed successfully
# City number 541 is saint simons
# saint simons processed successfully
# City number 542 is samarai
# samarai processed successfully
# City number 543 is tigwi
# No data for tigwi. Skipping tigwi
# City number 544 is rungata
# No data for rungata. Skipping rungata
# City number 545 is bushehr
# bushehr processed successfully
# City number 546 is suntar
# suntar processed successfully
# City number 547 is kalabo
# kalabo processed successfully
# City number 548 is yumen
# yumen processed successfully
# City number 549 is kloulklubed
# kloulklubed processed successfully
# City number 550 is samusu
# No data for samusu. Skipping samusu
# City number 551 is conselheiro pena
# conselheiro pena processed successfully
# City number 552 is neijiang
# neijiang processed successfully
# City number 553 is san cristobal
# san cristobal processed successfully
# City number 554 is strezhevoy
# strezhevoy processed successfully
# City number 555 is zeya
# zeya processed successfully
# City number 556 is chisec
# chisec processed successfully
# City number 557 is salinas
# salinas processed successfully
# City number 558 is maragogi
# maragogi processed successfully
# City number 559 is tonj
# tonj processed successfully

# %%
#create a dataframe for plotting
city_weather_df = pd.DataFrame(city_weather)

city_weather_df
# Out:
#                city  Latitude  Max Temp  Humidity  Cloudiness  Wind Speed
# 0         jamestown     42.10     71.60        43           1        3.36
# 1    port elizabeth    -33.92     50.00        93          67        4.70
# 2            kuytun     54.34     79.47        35           0        5.79
# 3      punta arenas    -53.15     24.80       100           0        5.48
# 4            albany     42.60     73.99        60          75        3.36
# ..              ...       ...       ...       ...         ...         ...
# 505            zeya     53.75     76.44        30          18        4.94
# 506          chisec     15.82     74.28        89         100        3.56
# 507         salinas     36.68     66.20        55           1       14.99
# 508        maragogi     -9.01     74.26        88          24        8.55
# 509            tonj      7.27     70.79        92         100        3.85
#
# [510 rows x 6 columns]

# %%
# Temperature (F) vs. Latitude Plot
plt.scatter(city_weather_df ["Latitude"], city_weather_df ["Max Temp"], marker="o", s=10)

# plot labels, x and y
plt.title("Temperature (F) vs. Latitude")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# Save the figure
plt.savefig("Plots/Temp_vs_Latitude.png")

# %%
# The data is showing that the temperature trends warmer in the cities in the latitudes between 0 and 40.

# %%
# Humidity (%) vs. Latitude Plot
plt.scatter(city_weather_df ["Latitude"], city_weather_df ["Humidity"], marker="o", s=10)

# plot labels, x and y
plt.title("Humidity (%) vs. Latitude Plot")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# Save the figure
plt.savefig("Plots/Humidity_vs_Latitude.png")

# %%
# This data shows that there can be high humidity in all latitudes

# %%
# Cloudiness (%) vs. Latitude Plot
plt.scatter(city_weather_df ["Latitude"], city_weather_df ["Cloudiness"], marker="o", s=10)

# plot labels, x and y
plt.title("Cloudiness (%) vs. Latitude Plot")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# Save the figure
plt.savefig("Plots/Cloudiness_vs_Latitude.png")

# %%
# This data shows that cloudiness varies in all latitudes

# %%
# Wind Speed (mph) vs. Latitude
plt.scatter(city_weather_df ["Latitude"], city_weather_df ["Wind Speed"], marker="o", s=10)

# plot labels, x and y
plt.title("Wind Speed (mph) vs. Latitude Plot")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# Save the figure
plt.savefig("Plots/Wind_vs_Latitude.png")

# %%
# This data shows that winds are mostly below 10 mph in all latitudes
