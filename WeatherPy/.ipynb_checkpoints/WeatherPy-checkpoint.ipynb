# %%
# !pip install git+git://github.com/geopandas/geopandas.git --quiet
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from citipy) (0.16)

# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
import numpy as np
from scipy import stats
from config import api_key
from random import uniform

# to find a city based on longitude and latitude
from citipy import citipy

# %%
# x, y = uniform(-180,180), uniform(-90, 90)

# def newpoint():
#    return uniform(-180,180), uniform(-90, 90)

# the_points = (newpoint() for x in range(15))
# for points in the_points:
# #    print(point)

# %%
# Create a set of random lat and lng combinations
lat_lngs =[]
lats = np.random.uniform(low=-90.000, high=90.000, size=1400)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1400)
lat_lngs = zip(lats, lngs)
# print(*lat_lngs)

# %%
# create a list to hold the cities
cities =[]

# Identify nearest city for each lat, lng combination
# for point in points:
#     city = citipy.nearest_city(point[0], point[1]).city_name
    
for points in lat_lngs:
    city = citipy.nearest_city(points[0], points[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
#     print(cities) 
# check the city count to make sure we have at least 500
len(cities)
#print(cities)
# Out:
# 587

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="
query_url

# set up lists to hold reponse info and city counter
city_weather = []
city_cnt = 1

print(f"There are {len(cities)}")
for city in cities:
    print(f"City number {city_cnt} is {city}")
    try:
        response = requests.get(query_url + city).json()
        city_lon = response['coord']['lon']
        city_lat = response['coord']['lat']
        city_mtemp = response['main']['temp_max']
        city_humidity = response['main']['humidity']
        city_clouds = response['clouds']['all']
        city_wspeed = response['wind']['speed']
        city_country = response['sys']['country']
        city_datetime = response['dt']
        city_weather.append({"city":city,
                      "Longitude":city_lon,
                      "Latitude":city_lat,
                      "Max Temp":city_mtemp,
                      "Humidity":city_humidity,
                      "Clouds":city_clouds,
                      "Wind Speed":city_wspeed,
                      "Country":city_country,
                      "Date Time":city_datetime,
                      })
        print(f"{city} processed successfully")
        city_cnt +=1
        
    except KeyError:
        print(f'No data for {city}. Skipping {city}')
        city_cnt +=1
# Out:
# There are 587
# City number 1 is yellowknife
# yellowknife processed successfully
# City number 2 is lavrentiya
# lavrentiya processed successfully
# City number 3 is longyearbyen
# longyearbyen processed successfully
# City number 4 is ballina
# ballina processed successfully
# City number 5 is kashi
# kashi processed successfully
# City number 6 is bambous virieux
# bambous virieux processed successfully
# City number 7 is barentsburg
# No data for barentsburg. Skipping barentsburg
# City number 8 is nikolskoye
# nikolskoye processed successfully
# City number 9 is illoqqortoormiut
# No data for illoqqortoormiut. Skipping illoqqortoormiut
# City number 10 is saint-philippe
# saint-philippe processed successfully
# City number 11 is kigali
# kigali processed successfully
# City number 12 is namatanai
# namatanai processed successfully
# City number 13 is qaanaaq
# qaanaaq processed successfully
# City number 14 is ushuaia
# ushuaia processed successfully
# City number 15 is bengkulu
# bengkulu processed successfully
# City number 16 is baie-comeau
# baie-comeau processed successfully
# City number 17 is faya
# faya processed successfully
# City number 18 is hilo
# hilo processed successfully
# City number 19 is dikson
# dikson processed successfully
# City number 20 is atuona
# atuona processed successfully
# City number 21 is sept-iles
# sept-iles processed successfully
# City number 22 is buqayq
# No data for buqayq. Skipping buqayq
# City number 23 is gulshat
# No data for gulshat. Skipping gulshat
# City number 24 is kaitangata
# kaitangata processed successfully
# City number 25 is mataura
# mataura processed successfully
# City number 26 is richards bay
# richards bay processed successfully
# City number 27 is leningradskiy
# leningradskiy processed successfully
# City number 28 is maltahohe
# maltahohe processed successfully
# City number 29 is busselton
# busselton processed successfully
# City number 30 is marrakesh
# marrakesh processed successfully
# City number 31 is kharan
# kharan processed successfully
# City number 32 is pandan
# pandan processed successfully
# City number 33 is bluff
# bluff processed successfully
# City number 34 is vestmannaeyjar
# vestmannaeyjar processed successfully
# City number 35 is inverness
# inverness processed successfully
# City number 36 is saint-louis
# saint-louis processed successfully
# City number 37 is san vicente
# san vicente processed successfully
# City number 38 is saleaula
# No data for saleaula. Skipping saleaula
# City number 39 is biak
# biak processed successfully
# City number 40 is taolanaro
# No data for taolanaro. Skipping taolanaro
# City number 41 is saint-georges
# saint-georges processed successfully
# City number 42 is barrow
# barrow processed successfully
# City number 43 is emba
# emba processed successfully
# City number 44 is bethel
# bethel processed successfully
# City number 45 is attawapiskat
# No data for attawapiskat. Skipping attawapiskat
# City number 46 is vaini
# vaini processed successfully
# City number 47 is punta arenas
# punta arenas processed successfully
# City number 48 is longyan
# longyan processed successfully
# City number 49 is along
# along processed successfully
# City number 50 is hithadhoo
# hithadhoo processed successfully
# City number 51 is bonthe
# bonthe processed successfully
# City number 52 is port elizabeth
# port elizabeth processed successfully
# City number 53 is lokosovo
# lokosovo processed successfully
# City number 54 is saskylakh
# saskylakh processed successfully
# City number 55 is broome
# broome processed successfully
# City number 56 is codrington
# codrington processed successfully
# City number 57 is kiknur
# kiknur processed successfully
# City number 58 is nyaunglebin
# nyaunglebin processed successfully
# City number 59 is rikitea
# rikitea processed successfully
# City number 60 is olinda
# olinda processed successfully
# City number 61 is olafsvik
# olafsvik processed successfully
# City number 62 is cape town
# cape town processed successfully
# City number 63 is chulym
# chulym processed successfully
# City number 64 is sao filipe
# sao filipe processed successfully
# City number 65 is northam
# northam processed successfully
# City number 66 is sorland
# sorland processed successfully
# City number 67 is tsihombe
# No data for tsihombe. Skipping tsihombe
# City number 68 is caravelas
# caravelas processed successfully
# City number 69 is shirhatti
# shirhatti processed successfully
# City number 70 is san quintin
# san quintin processed successfully
# City number 71 is arcata
# arcata processed successfully
# City number 72 is grand river south east
# No data for grand river south east. Skipping grand river south east
# City number 73 is lagoa
# lagoa processed successfully
# City number 74 is mar del plata
# mar del plata processed successfully
# City number 75 is natal
# natal processed successfully
# City number 76 is fortuna
# fortuna processed successfully
# City number 77 is acapulco
# acapulco processed successfully
# City number 78 is hobart
# hobart processed successfully
# City number 79 is kazalinsk
# No data for kazalinsk. Skipping kazalinsk
# City number 80 is lorengau
# lorengau processed successfully
# City number 81 is jinchang
# jinchang processed successfully
# City number 82 is texarkana
# texarkana processed successfully
# City number 83 is mount gambier
# mount gambier processed successfully
# City number 84 is khatanga
# khatanga processed successfully
# City number 85 is lolua
# No data for lolua. Skipping lolua
# City number 86 is myitkyina
# myitkyina processed successfully
# City number 87 is kinshasa
# kinshasa processed successfully
# City number 88 is bubaque
# bubaque processed successfully
# City number 89 is narsaq
# narsaq processed successfully
# City number 90 is teya
# teya processed successfully
# City number 91 is youkounkoun
# youkounkoun processed successfully
# City number 92 is lasa
# lasa processed successfully
# City number 93 is vorontsovka
# vorontsovka processed successfully
# City number 94 is tuktoyaktuk
# tuktoyaktuk processed successfully
# City number 95 is deputatskiy
# deputatskiy processed successfully
# City number 96 is yulara
# yulara processed successfully
# City number 97 is puerto ayora
# puerto ayora processed successfully
# City number 98 is jamestown
# jamestown processed successfully
# City number 99 is severo-kurilsk
# severo-kurilsk processed successfully
# City number 100 is tuatapere
# tuatapere processed successfully
# City number 101 is tiznit
# tiznit processed successfully
# City number 102 is alta floresta
# alta floresta processed successfully
# City number 103 is bolungarvik
# No data for bolungarvik. Skipping bolungarvik
# City number 104 is ponta do sol
# ponta do sol processed successfully
# City number 105 is butaritari
# butaritari processed successfully
# City number 106 is sokolo
# sokolo processed successfully
# City number 107 is nizhneyansk
# No data for nizhneyansk. Skipping nizhneyansk
# City number 108 is klaksvik
# klaksvik processed successfully
# City number 109 is whitianga
# whitianga processed successfully
# City number 110 is krutikha
# krutikha processed successfully
# City number 111 is libreville
# libreville processed successfully
# City number 112 is amderma
# No data for amderma. Skipping amderma
# City number 113 is gimli
# gimli processed successfully
# City number 114 is kangaatsiaq
# kangaatsiaq processed successfully
# City number 115 is college
# college processed successfully
# City number 116 is duz
# No data for duz. Skipping duz
# City number 117 is victoria
# victoria processed successfully
# City number 118 is luderitz
# luderitz processed successfully
# City number 119 is comarapa
# comarapa processed successfully
# City number 120 is srednekolymsk
# srednekolymsk processed successfully
# City number 121 is saint george
# saint george processed successfully
# City number 122 is roald
# roald processed successfully
# City number 123 is kapaa
# kapaa processed successfully
# City number 124 is jamui
# jamui processed successfully
# City number 125 is port alfred
# port alfred processed successfully
# City number 126 is reconquista
# reconquista processed successfully
# City number 127 is barcelos
# barcelos processed successfully
# City number 128 is nabire
# nabire processed successfully
# City number 129 is berlevag
# berlevag processed successfully
# City number 130 is hermanus
# hermanus processed successfully
# City number 131 is shingu
# shingu processed successfully
# City number 132 is albany
# albany processed successfully
# City number 133 is great yarmouth
# great yarmouth processed successfully
# City number 134 is coquimbo
# coquimbo processed successfully
# City number 135 is kavieng
# kavieng processed successfully
# City number 136 is bourail
# bourail processed successfully
# City number 137 is shakhovskaya
# shakhovskaya processed successfully
# City number 138 is dingle
# dingle processed successfully
# City number 139 is taltal
# taltal processed successfully
# City number 140 is nome
# nome processed successfully
# City number 141 is hobyo
# hobyo processed successfully
# City number 142 is kasongo-lunda
# kasongo-lunda processed successfully
# City number 143 is formosa
# formosa processed successfully
# City number 144 is kachug
# kachug processed successfully
# City number 145 is los llanos de aridane
# los llanos de aridane processed successfully
# City number 146 is la asuncion
# la asuncion processed successfully
# City number 147 is salinopolis
# salinopolis processed successfully
# City number 148 is kazerun
# kazerun processed successfully
# City number 149 is pitlochry
# pitlochry processed successfully
# City number 150 is esperance
# esperance processed successfully
# City number 151 is iqaluit
# iqaluit processed successfully
# City number 152 is lompoc
# lompoc processed successfully
# City number 153 is bredasdorp
# bredasdorp processed successfully
# City number 154 is walvis bay
# walvis bay processed successfully
# City number 155 is lebu
# lebu processed successfully
# City number 156 is upernavik
# upernavik processed successfully
# City number 157 is saint-augustin
# saint-augustin processed successfully
# City number 158 is margate
# margate processed successfully
# City number 159 is kidero
# kidero processed successfully
# City number 160 is itoman
# itoman processed successfully
# City number 161 is ancud
# ancud processed successfully
# City number 162 is hambantota
# hambantota processed successfully
# City number 163 is norman wells
# norman wells processed successfully
# City number 164 is mys shmidta
# No data for mys shmidta. Skipping mys shmidta
# City number 165 is vila franca do campo
# vila franca do campo processed successfully
# City number 166 is ridgecrest
# ridgecrest processed successfully
# City number 167 is puerto escondido
# puerto escondido processed successfully
# City number 168 is alotau
# No data for alotau. Skipping alotau
# City number 169 is sao joao da barra
# sao joao da barra processed successfully
# City number 170 is odweyne
# odweyne processed successfully
# City number 171 is saint anthony
# saint anthony processed successfully
# City number 172 is uvat
# uvat processed successfully
# City number 173 is faanui
# faanui processed successfully
# City number 174 is halifax
# halifax processed successfully
# City number 175 is katherine
# katherine processed successfully
# City number 176 is itarema
# itarema processed successfully
# City number 177 is warqla
# No data for warqla. Skipping warqla
# City number 178 is chuy
# chuy processed successfully
# City number 179 is baruun-urt
# baruun-urt processed successfully
# City number 180 is bagdarin
# bagdarin processed successfully
# City number 181 is georgetown
# georgetown processed successfully
# City number 182 is matagami
# matagami processed successfully
# City number 183 is provideniya
# provideniya processed successfully
# City number 184 is grand gaube
# grand gaube processed successfully
# City number 185 is paracuru
# paracuru processed successfully
# City number 186 is saint-pierre
# saint-pierre processed successfully
# City number 187 is andevoranto
# No data for andevoranto. Skipping andevoranto
# City number 188 is marcona
# No data for marcona. Skipping marcona
# City number 189 is xai-xai
# xai-xai processed successfully
# City number 190 is juneau
# juneau processed successfully
# City number 191 is quatre cocos
# quatre cocos processed successfully
# City number 192 is kahului
# kahului processed successfully
# City number 193 is tasiilaq
# tasiilaq processed successfully
# City number 194 is trairi
# trairi processed successfully
# City number 195 is nishihara
# nishihara processed successfully
# City number 196 is svobodnyy
# svobodnyy processed successfully
# City number 197 is thompson
# thompson processed successfully
# City number 198 is chokurdakh
# chokurdakh processed successfully
# City number 199 is raudeberg
# raudeberg processed successfully
# City number 200 is new norfolk
# new norfolk processed successfully
# City number 201 is forlimpopoli
# forlimpopoli processed successfully
# City number 202 is taoudenni
# taoudenni processed successfully
# City number 203 is mogok
# mogok processed successfully
# City number 204 is save
# save processed successfully
# City number 205 is mahebourg
# mahebourg processed successfully
# City number 206 is solnechnyy
# solnechnyy processed successfully
# City number 207 is guerrero negro
# guerrero negro processed successfully
# City number 208 is moroni
# moroni processed successfully
# City number 209 is tuskegee
# tuskegee processed successfully
# City number 210 is karakol
# karakol processed successfully
# City number 211 is pevek
# pevek processed successfully
# City number 212 is tarlungeni
# tarlungeni processed successfully
# City number 213 is avarua
# avarua processed successfully
# City number 214 is temiscaming
# temiscaming processed successfully
# City number 215 is gold coast
# gold coast processed successfully
# City number 216 is amapa
# amapa processed successfully
# City number 217 is gangotri
# No data for gangotri. Skipping gangotri
# City number 218 is novi sanzhary
# novi sanzhary processed successfully
# City number 219 is pingliang
# pingliang processed successfully
# City number 220 is hasaki
# hasaki processed successfully
# City number 221 is dongsheng
# dongsheng processed successfully
# City number 222 is norden
# norden processed successfully
# City number 223 is sitka
# sitka processed successfully
# City number 224 is bashtanka
# bashtanka processed successfully
# City number 225 is geresk
# No data for geresk. Skipping geresk
# City number 226 is carnarvon
# carnarvon processed successfully
# City number 227 is arraial do cabo
# arraial do cabo processed successfully
# City number 228 is sibolga
# sibolga processed successfully
# City number 229 is north platte
# north platte processed successfully
# City number 230 is satitoa
# No data for satitoa. Skipping satitoa
# City number 231 is road town
# road town processed successfully
# City number 232 is aswan
# aswan processed successfully
# City number 233 is magdagachi
# magdagachi processed successfully
# City number 234 is camopi
# camopi processed successfully
# City number 235 is yar-sale
# yar-sale processed successfully
# City number 236 is liyang
# liyang processed successfully
# City number 237 is komsomolskiy
# komsomolskiy processed successfully
# City number 238 is saldanha
# saldanha processed successfully
# City number 239 is henties bay
# henties bay processed successfully
# City number 240 is preobrazheniye
# preobrazheniye processed successfully
# City number 241 is vila
# vila processed successfully
# City number 242 is mizdah
# mizdah processed successfully
# City number 243 is nouadhibou
# nouadhibou processed successfully
# City number 244 is airai
# airai processed successfully
# City number 245 is champerico
# champerico processed successfully
# City number 246 is awbari
# awbari processed successfully
# City number 247 is hirara
# hirara processed successfully
# City number 248 is tiksi
# tiksi processed successfully
# City number 249 is samana
# samana processed successfully
# City number 250 is salalah
# salalah processed successfully
# City number 251 is pemangkat
# pemangkat processed successfully
# City number 252 is les cayes
# les cayes processed successfully
# City number 253 is ahipara
# ahipara processed successfully
# City number 254 is malwan
# No data for malwan. Skipping malwan
# City number 255 is makung
# No data for makung. Skipping makung
# City number 256 is kondinskoye
# kondinskoye processed successfully
# City number 257 is belushya guba
# No data for belushya guba. Skipping belushya guba
# City number 258 is sobolevo
# sobolevo processed successfully
# City number 259 is pitimbu
# pitimbu processed successfully
# City number 260 is ulaanbaatar
# ulaanbaatar processed successfully
# City number 261 is ipixuna
# ipixuna processed successfully
# City number 262 is ilanskiy
# ilanskiy processed successfully
# City number 263 is kamaishi
# kamaishi processed successfully
# City number 264 is camacha
# camacha processed successfully
# City number 265 is ostrovnoy
# ostrovnoy processed successfully
# City number 266 is manaus
# manaus processed successfully
# City number 267 is ribeira grande
# ribeira grande processed successfully
# City number 268 is kambar
# kambar processed successfully
# City number 269 is torbay
# torbay processed successfully
# City number 270 is pula
# pula processed successfully
# City number 271 is maracanau
# maracanau processed successfully
# City number 272 is khonuu
# No data for khonuu. Skipping khonuu
# City number 273 is abu dhabi
# abu dhabi processed successfully
# City number 274 is cabedelo
# cabedelo processed successfully
# City number 275 is sentyabrskiy
# No data for sentyabrskiy. Skipping sentyabrskiy
# City number 276 is okha
# okha processed successfully
# City number 277 is vaitupu
# No data for vaitupu. Skipping vaitupu
# City number 278 is emerald
# emerald processed successfully
# City number 279 is sinegorye
# sinegorye processed successfully
# City number 280 is kapuskasing
# kapuskasing processed successfully
# City number 281 is ambunti
# ambunti processed successfully
# City number 282 is oda
# oda processed successfully
# City number 283 is rocha
# rocha processed successfully
# City number 284 is tumannyy
# No data for tumannyy. Skipping tumannyy
# City number 285 is cabo san lucas
# cabo san lucas processed successfully
# City number 286 is strezhevoy
# strezhevoy processed successfully
# City number 287 is geraldton
# geraldton processed successfully
# City number 288 is kamenka
# kamenka processed successfully
# City number 289 is baturaja
# baturaja processed successfully
# City number 290 is ornes
# ornes processed successfully
# City number 291 is olkhovka
# olkhovka processed successfully
# City number 292 is port lincoln
# port lincoln processed successfully
# City number 293 is ayan
# ayan processed successfully
# City number 294 is lakes entrance
# lakes entrance processed successfully
# City number 295 is gorkovskoye
# No data for gorkovskoye. Skipping gorkovskoye
# City number 296 is katsuura
# katsuura processed successfully
# City number 297 is torrijos
# torrijos processed successfully
# City number 298 is teguise
# teguise processed successfully
# City number 299 is krasnoselkup
# krasnoselkup processed successfully
# City number 300 is tomohon
# tomohon processed successfully
# City number 301 is talcahuano
# talcahuano processed successfully
# City number 302 is bathsheba
# bathsheba processed successfully
# City number 303 is havre de grace
# havre de grace processed successfully
# City number 304 is yumen
# yumen processed successfully
# City number 305 is port augusta
# port augusta processed successfully
# City number 306 is talnakh
# talnakh processed successfully
# City number 307 is borama
# No data for borama. Skipping borama
# City number 308 is wundanyi
# wundanyi processed successfully
# City number 309 is vila velha
# vila velha processed successfully
# City number 310 is rudnogorsk
# rudnogorsk processed successfully
# City number 311 is nsanje
# nsanje processed successfully
# City number 312 is sataua
# No data for sataua. Skipping sataua
# City number 313 is abu samrah
# abu samrah processed successfully
# City number 314 is helena
# helena processed successfully
# City number 315 is truckee
# truckee processed successfully
# City number 316 is san bartolome de tirajana
# san bartolome de tirajana processed successfully
# City number 317 is ambositra
# ambositra processed successfully
# City number 318 is westerland
# westerland processed successfully
# City number 319 is batsfjord
# batsfjord processed successfully
# City number 320 is haimen
# haimen processed successfully
# City number 321 is minot
# minot processed successfully
# City number 322 is otane
# otane processed successfully
# City number 323 is husavik
# husavik processed successfully
# City number 324 is sambava
# sambava processed successfully
# City number 325 is kirakira
# kirakira processed successfully
# City number 326 is lata
# lata processed successfully
# City number 327 is brezno
# brezno processed successfully
# City number 328 is anloga
# anloga processed successfully
# City number 329 is port hedland
# port hedland processed successfully
# City number 330 is ingleside
# ingleside processed successfully
# City number 331 is san luis
# san luis processed successfully
# City number 332 is moron
# moron processed successfully
# City number 333 is paithan
# paithan processed successfully
# City number 334 is kruisfontein
# kruisfontein processed successfully
# City number 335 is gamba
# gamba processed successfully
# City number 336 is teahupoo
# teahupoo processed successfully
# City number 337 is isangel
# isangel processed successfully
# City number 338 is sola
# sola processed successfully
# City number 339 is sivas
# sivas processed successfully
# City number 340 is salekhard
# salekhard processed successfully
# City number 341 is lalmohan
# lalmohan processed successfully
# City number 342 is opunake
# opunake processed successfully
# City number 343 is zeya
# zeya processed successfully
# City number 344 is thai binh
# thai binh processed successfully
# City number 345 is bambanglipuro
# bambanglipuro processed successfully
# City number 346 is castro
# castro processed successfully
# City number 347 is ambilobe
# ambilobe processed successfully
# City number 348 is sorvag
# No data for sorvag. Skipping sorvag
# City number 349 is labuhan
# labuhan processed successfully
# City number 350 is hendek
# hendek processed successfully
# City number 351 is xingyi
# xingyi processed successfully
# City number 352 is nuuk
# nuuk processed successfully
# City number 353 is yerbogachen
# yerbogachen processed successfully
# City number 354 is tautira
# tautira processed successfully
# City number 355 is clyde river
# clyde river processed successfully
# City number 356 is touros
# touros processed successfully
# City number 357 is haines junction
# haines junction processed successfully
# City number 358 is sandane
# sandane processed successfully
# City number 359 is kalabo
# kalabo processed successfully
# City number 360 is casas grandes
# casas grandes processed successfully
# City number 361 is avera
# avera processed successfully
# City number 362 is novyy urengoy
# novyy urengoy processed successfully
# City number 363 is constitucion
# constitucion processed successfully
# City number 364 is honiara
# honiara processed successfully
# City number 365 is karaton
# karaton processed successfully
# City number 366 is las vegas
# las vegas processed successfully
# City number 367 is samalaeulu
# No data for samalaeulu. Skipping samalaeulu
# City number 368 is umzimvubu
# No data for umzimvubu. Skipping umzimvubu
# City number 369 is belyy yar
# belyy yar processed successfully
# City number 370 is pemba
# pemba processed successfully
# City number 371 is rungata
# No data for rungata. Skipping rungata
# City number 372 is zhigansk
# zhigansk processed successfully
# City number 373 is paita
# paita processed successfully
# City number 374 is honningsvag
# honningsvag processed successfully
# City number 375 is rantepao
# rantepao processed successfully
# City number 376 is port hardy
# port hardy processed successfully
# City number 377 is nushki
# nushki processed successfully
# City number 378 is methoni
# methoni processed successfully
# City number 379 is berikulskiy
# No data for berikulskiy. Skipping berikulskiy
# City number 380 is brae
# brae processed successfully
# City number 381 is port keats
# port keats processed successfully
# City number 382 is melo
# melo processed successfully
# City number 383 is sundsvall
# sundsvall processed successfully
# City number 384 is dalianwan
# dalianwan processed successfully
# City number 385 is ust-kuyga
# ust-kuyga processed successfully
# City number 386 is tomelloso
# tomelloso processed successfully
# City number 387 is san policarpo
# san policarpo processed successfully
# City number 388 is kamariotissa
# kamariotissa processed successfully
# City number 389 is havelock
# havelock processed successfully
# City number 390 is aklavik
# aklavik processed successfully
# City number 391 is hami
# hami processed successfully
# City number 392 is sao gabriel da cachoeira
# sao gabriel da cachoeira processed successfully
# City number 393 is niquero
# niquero processed successfully
# City number 394 is portland
# portland processed successfully
# City number 395 is teguldet
# teguldet processed successfully
# City number 396 is batagay-alyta
# batagay-alyta processed successfully
# City number 397 is buariki
# No data for buariki. Skipping buariki
# City number 398 is mvuma
# mvuma processed successfully
# City number 399 is chitrakonda
# chitrakonda processed successfully
# City number 400 is half moon bay
# half moon bay processed successfully
# City number 401 is ilulissat
# ilulissat processed successfully
# City number 402 is novoorsk
# novoorsk processed successfully
# City number 403 is mashhad
# mashhad processed successfully
# City number 404 is okhotsk
# okhotsk processed successfully
# City number 405 is santo tomas
# santo tomas processed successfully
# City number 406 is kodiak
# kodiak processed successfully
# City number 407 is bakchar
# bakchar processed successfully
# City number 408 is namsos
# namsos processed successfully
# City number 409 is louisbourg
# No data for louisbourg. Skipping louisbourg
# City number 410 is bandarbeyla
# bandarbeyla processed successfully
# City number 411 is vardo
# vardo processed successfully
# City number 412 is calabozo
# calabozo processed successfully
# City number 413 is kloulklubed
# kloulklubed processed successfully
# City number 414 is dumas
# dumas processed successfully
# City number 415 is pangnirtung
# pangnirtung processed successfully
# City number 416 is vanavara
# vanavara processed successfully
# City number 417 is nelson bay
# nelson bay processed successfully
# City number 418 is fare
# fare processed successfully
# City number 419 is cidreira
# cidreira processed successfully
# City number 420 is piacabucu
# piacabucu processed successfully
# City number 421 is whitehorse
# whitehorse processed successfully
# City number 422 is ixtapa
# ixtapa processed successfully
# City number 423 is guarapari
# guarapari processed successfully
# City number 424 is maragogi
# maragogi processed successfully
# City number 425 is malanje
# malanje processed successfully
# City number 426 is najran
# najran processed successfully
# City number 427 is portalegre
# portalegre processed successfully
# City number 428 is palabuhanratu
# No data for palabuhanratu. Skipping palabuhanratu
# City number 429 is arandis
# arandis processed successfully
# City number 430 is east london
# east london processed successfully
# City number 431 is carquefou
# carquefou processed successfully
# City number 432 is tiarei
# tiarei processed successfully
# City number 433 is port blair
# port blair processed successfully
# City number 434 is ndende
# ndende processed successfully
# City number 435 is vao
# vao processed successfully
# City number 436 is kutum
# kutum processed successfully
# City number 437 is pedernales
# pedernales processed successfully
# City number 438 is souillac
# souillac processed successfully
# City number 439 is xichang
# xichang processed successfully
# City number 440 is huarmey
# huarmey processed successfully
# City number 441 is lichtenau
# lichtenau processed successfully
# City number 442 is mulheim-karlich
# mulheim-karlich processed successfully
# City number 443 is bilibino
# bilibino processed successfully
# City number 444 is nanortalik
# nanortalik processed successfully
# City number 445 is mayo
# mayo processed successfully
# City number 446 is makaryev
# makaryev processed successfully
# City number 447 is anchorage
# anchorage processed successfully
# City number 448 is noumea
# noumea processed successfully
# City number 449 is biltine
# biltine processed successfully
# City number 450 is calatayud
# calatayud processed successfully
# City number 451 is namwala
# namwala processed successfully
# City number 452 is beyneu
# beyneu processed successfully
# City number 453 is slonim
# slonim processed successfully
# City number 454 is hualmay
# hualmay processed successfully
# City number 455 is moussoro
# moussoro processed successfully
# City number 456 is oranjemund
# oranjemund processed successfully
# City number 457 is gobabis
# gobabis processed successfully
# City number 458 is akropong
# akropong processed successfully
# City number 459 is saltpond
# saltpond processed successfully
# City number 460 is kargasok
# kargasok processed successfully
# City number 461 is dwarka
# dwarka processed successfully
# City number 462 is iisalmi
# iisalmi processed successfully
# City number 463 is paamiut
# paamiut processed successfully
# City number 464 is kendari
# kendari processed successfully
# City number 465 is fort nelson
# fort nelson processed successfully
# City number 466 is shchelyayur
# No data for shchelyayur. Skipping shchelyayur
# City number 467 is portree
# portree processed successfully
# City number 468 is luena
# luena processed successfully
# City number 469 is kandrian
# kandrian processed successfully
# City number 470 is inhambane
# inhambane processed successfully
# City number 471 is te anau
# te anau processed successfully
# City number 472 is nokha
# nokha processed successfully
# City number 473 is havre-saint-pierre
# havre-saint-pierre processed successfully
# City number 474 is lufilufi
# lufilufi processed successfully
# City number 475 is horsham
# horsham processed successfully
# City number 476 is caconda
# caconda processed successfully
# City number 477 is saint-ambroise
# saint-ambroise processed successfully
# City number 478 is tingrela
# No data for tingrela. Skipping tingrela
# City number 479 is baherden
# baherden processed successfully
# City number 480 is dong hoi
# dong hoi processed successfully
# City number 481 is houlton
# houlton processed successfully
# City number 482 is valley station
# valley station processed successfully
# City number 483 is san cristobal
# san cristobal processed successfully
# City number 484 is am timan
# am timan processed successfully
# City number 485 is shorapani
# shorapani processed successfully
# City number 486 is inuvik
# inuvik processed successfully
# City number 487 is yablonovo
# yablonovo processed successfully
# City number 488 is roanoke rapids
# roanoke rapids processed successfully
# City number 489 is kendal
# kendal processed successfully
# City number 490 is trincomalee
# trincomalee processed successfully
# City number 491 is sayat
# sayat processed successfully
# City number 492 is bada
# bada processed successfully
# City number 493 is chivay
# chivay processed successfully
# City number 494 is barbar
# No data for barbar. Skipping barbar
# City number 495 is groton
# groton processed successfully
# City number 496 is luba
# luba processed successfully
# City number 497 is morondava
# morondava processed successfully
# City number 498 is arlit
# arlit processed successfully
# City number 499 is jardim
# jardim processed successfully
# City number 500 is lima
# lima processed successfully
# City number 501 is antsohihy
# antsohihy processed successfully
# City number 502 is hebertville
# No data for hebertville. Skipping hebertville
# City number 503 is gueret
# gueret processed successfully
# City number 504 is dakar
# dakar processed successfully
# City number 505 is ajdabiya
# ajdabiya processed successfully
# City number 506 is prince rupert
# prince rupert processed successfully
# City number 507 is maceio
# maceio processed successfully
# City number 508 is lahad datu
# lahad datu processed successfully
# City number 509 is ucar
# ucar processed successfully
# City number 510 is namibe
# namibe processed successfully
# City number 511 is ituni
# No data for ituni. Skipping ituni
# City number 512 is simnas
# simnas processed successfully
# City number 513 is pandan niog
# pandan niog processed successfully
# City number 514 is grootfontein
# grootfontein processed successfully
# City number 515 is huancavelica
# huancavelica processed successfully
# City number 516 is rence
# rence processed successfully
# City number 517 is moose factory
# moose factory processed successfully
# City number 518 is hay river
# hay river processed successfully
# City number 519 is eyl
# eyl processed successfully
# City number 520 is ponnani
# ponnani processed successfully
# City number 521 is selje
# selje processed successfully
# City number 522 is paragominas
# paragominas processed successfully
# City number 523 is samfya
# samfya processed successfully
# City number 524 is cherskiy
# cherskiy processed successfully
# City number 525 is butembo
# butembo processed successfully
# City number 526 is chengde
# chengde processed successfully
# City number 527 is la ronge
# la ronge processed successfully
# City number 528 is kuva
# No data for kuva. Skipping kuva
# City number 529 is bethanien
# bethanien processed successfully
# City number 530 is atikokan
# atikokan processed successfully
# City number 531 is obanazawa
# obanazawa processed successfully
# City number 532 is shelburne
# shelburne processed successfully
# City number 533 is huari
# huari processed successfully
# City number 534 is ola
# ola processed successfully
# City number 535 is villa carlos paz
# villa carlos paz processed successfully
# City number 536 is bagotville
# bagotville processed successfully
# City number 537 is aflu
# No data for aflu. Skipping aflu
# City number 538 is rock springs
# rock springs processed successfully
# City number 539 is maua
# maua processed successfully
# City number 540 is yanan
# No data for yanan. Skipping yanan
# City number 541 is port shepstone
# port shepstone processed successfully
# City number 542 is surskoye
# surskoye processed successfully
# City number 543 is hawkesbury
# hawkesbury processed successfully
# City number 544 is ternate
# ternate processed successfully
# City number 545 is keti bandar
# keti bandar processed successfully
# City number 546 is padang
# padang processed successfully
# City number 547 is kihei
# kihei processed successfully
# City number 548 is aykhal
# aykhal processed successfully
# City number 549 is belmonte
# belmonte processed successfully
# City number 550 is san ramon
# san ramon processed successfully
# City number 551 is riobamba
# riobamba processed successfully
# City number 552 is panzhihua
# panzhihua processed successfully
# City number 553 is seybaplaya
# seybaplaya processed successfully
# City number 554 is tura
# tura processed successfully
# City number 555 is oussouye
# oussouye processed successfully
# City number 556 is kupang
# kupang processed successfully
# City number 557 is talara
# talara processed successfully
# City number 558 is yelkhovka
# yelkhovka processed successfully
# City number 559 is mitchell
# mitchell processed successfully
# City number 560 is one hundred mile house
# No data for one hundred mile house. Skipping one hundred mile house
# City number 561 is shitanjing
# shitanjing processed successfully
# City number 562 is ouegoa
# ouegoa processed successfully
# City number 563 is buala
# buala processed successfully
# City number 564 is phaltan
# phaltan processed successfully
# City number 565 is prainha
# prainha processed successfully
# City number 566 is somerset west
# somerset west processed successfully
# City number 567 is suntar
# suntar processed successfully
# City number 568 is lalomanu
# No data for lalomanu. Skipping lalomanu
# City number 569 is asyut
# asyut processed successfully
# City number 570 is westport
# westport processed successfully
# City number 571 is scarborough
# scarborough processed successfully
# City number 572 is mezen
# mezen processed successfully
# City number 573 is dharmadam
# dharmadam processed successfully
# City number 574 is marawi
# marawi processed successfully
# City number 575 is grindavik
# grindavik processed successfully
# City number 576 is ngunguru
# ngunguru processed successfully
# City number 577 is jalu
# jalu processed successfully
# City number 578 is croy
# croy processed successfully
# City number 579 is andilamena
# andilamena processed successfully
# City number 580 is rebrikha
# rebrikha processed successfully
# City number 581 is vagay
# vagay processed successfully
# City number 582 is pisco
# pisco processed successfully
# City number 583 is high rock
# high rock processed successfully
# City number 584 is gryazovets
# gryazovets processed successfully
# City number 585 is naryan-mar
# naryan-mar processed successfully
# City number 586 is kaihua
# kaihua processed successfully
# City number 587 is riyadh
# riyadh processed successfully

# %%
#create a dataframe for plotting
city_weather_df = pd.DataFrame(city_weather)

city_weather_df
# Out:
#              city  Longitude  Latitude  Max Temp  Humidity  Clouds  \
# 0     yellowknife    -114.35     62.46     57.20        71      20
# 1      lavrentiya    -171.00     65.58     49.71        90      99
# 2    longyearbyen      15.64     78.22     50.00        71      40
# 3         ballina     153.57    -28.87     64.40        59       0
# 4           kashi      75.98     39.45     80.60        22       0
# ..            ...        ...       ...       ...       ...     ...
# 531     high rock     -78.28     26.62     83.23        67     100
# 532    gryazovets      40.25     58.88     72.55        65       2
# 533    naryan-mar      53.09     67.67     69.17        72      84
# 534        kaihua     104.28     23.37     80.37        70      98
# 535        riyadh      46.72     24.69    104.00        11     100
#
#      Wind Speed Country   Date Time
# 0          3.36      CA  1594019481
# 1          5.19      RU  1594018932
# 2         14.99      SJ  1594018932
# 3         10.29      AU  1594018932
# 4          6.71      CN  1594019530
# ..          ...     ...         ...
# 531        4.88      BS  1594018962
# 532       10.36      RU  1594018962
# 533       11.30      RU  1594018962
# 534       12.39      CN  1594018962
# 535        6.93      SA  1594018862
#
# [536 rows x 9 columns]

# %%
# Temperature (F) vs. Latitude Plot
plt.scatter(city_weather_df ["Latitude"], city_weather_df ["Max Temp"], marker="o", s=10)

# plot labels, x and y
plt.title("Temperature (F) vs. Latitude")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# Save the figure
plt.savefig("Plots/Temp_vs_Latitude.png")

# %%
# The data is showing that the temperature trends warmer in the cities in the latitudes between 0 and 40.

# %%
# Humidity (%) vs. Latitude Plot
plt.scatter(city_weather_df ["Latitude"], city_weather_df ["Humidity"], marker="o", s=10)

# plot labels, x and y
plt.title("Humidity (%) vs. Latitude Plot")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# Save the figure
plt.savefig("Plots/Humidity_vs_Latitude.png")

# %%
# This data shows that there can be high humidity in all latitudes

# %%
# Cloudiness (%) vs. Latitude Plot
plt.scatter(city_weather_df ["Latitude"], city_weather_df ["Clouds"], marker="o", s=10)

# plot labels, x and y
plt.title("Cloudiness (%) vs. Latitude Plot")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# Save the figure
plt.savefig("Plots/Cloudiness_vs_Latitude.png")

# %%
# This data shows that cloudiness varies in all latitudes

# %%
# Wind Speed (mph) vs. Latitude
plt.scatter(city_weather_df ["Latitude"], city_weather_df ["Wind Speed"], marker="o", s=10)

# plot labels, x and y
plt.title("Wind Speed (mph) vs. Latitude Plot")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# Save the figure
plt.savefig("Plots/Wind_vs_Latitude.png")

# %%
# This data shows that winds are mostly below 10 mph in all latitudes

# %%
# Save a CSV of all retrieved data
city_weather_df.to_csv("city_weather_data.csv")

# %%
# # Perform a linear regression on Northern Hemisphere - Temperature (F) vs. Latitude
# (slope, intercept, rvalue, pvalue, stderr) = stats.linregress(city_weather_df ["Latitude"], city_weather_df ["Max Temp"])

# # Get regression values
# regress_values = city_weather_df ["Latitude"] * slope + intercept
# print(regress_values)

# %%
# Seperate the northern and southern Hemisphere
northern_cities = city_weather_df[(city_weather_df["Latitude"] >= 0)]
northern_cities
# Out:
#              city  Longitude  Latitude  Max Temp  Humidity  Clouds  \
# 0     yellowknife    -114.35     62.46     57.20        71      20
# 1      lavrentiya    -171.00     65.58     49.71        90      99
# 2    longyearbyen      15.64     78.22     50.00        71      40
# 4           kashi      75.98     39.45     80.60        22       0
# 6      nikolskoye      30.79     59.70     66.20        68      75
# ..            ...        ...       ...       ...       ...     ...
# 531     high rock     -78.28     26.62     83.23        67     100
# 532    gryazovets      40.25     58.88     72.55        65       2
# 533    naryan-mar      53.09     67.67     69.17        72      84
# 534        kaihua     104.28     23.37     80.37        70      98
# 535        riyadh      46.72     24.69    104.00        11     100
#
#      Wind Speed Country   Date Time
# 0          3.36      CA  1594019481
# 1          5.19      RU  1594018932
# 2         14.99      SJ  1594018932
# 4          6.71      CN  1594019530
# 6         15.66      RU  1594019530
# ..          ...     ...         ...
# 531        4.88      BS  1594018962
# 532       10.36      RU  1594018962
# 533       11.30      RU  1594018962
# 534       12.39      CN  1594018962
# 535        6.93      SA  1594018862
#
# [358 rows x 9 columns]

# %%
southern_cities = city_weather_df[(city_weather_df["Latitude"] < 0)]
southern_cities
# Out:
#                 city  Longitude  Latitude  Max Temp  Humidity  Clouds  \
# 3            ballina     153.57    -28.87     64.40        59       0
# 5    bambous virieux      57.76    -20.34     77.00        94      75
# 7     saint-philippe      55.77    -21.36     75.20        78      75
# 8             kigali      30.06     -1.95     66.20        72      75
# 9          namatanai     152.43     -3.67     82.58        75      90
# ..               ...        ...       ...       ...       ...     ...
# 514          prainha     -53.48     -1.80     72.70        95      64
# 515    somerset west      18.82    -34.08     48.20        93      20
# 524         ngunguru     174.50    -35.62     51.01        91       1
# 527       andilamena      48.58    -17.02     65.77        69      78
# 530            pisco     -76.22    -13.70     57.20        93      90
#
#      Wind Speed Country   Date Time
# 3         10.29      AU  1594018932
# 5         11.41      MU  1594019530
# 7         16.11      RE  1594019530
# 8          2.24      RW  1594018806
# 9          6.89      PG  1594018932
# ..          ...     ...         ...
# 514        3.27      BR  1594018961
# 515        3.36      ZA  1594018961
# 524        1.99      NZ  1594018961
# 527        9.84      MG  1594018962
# 530        4.70      PE  1594019553
#
# [178 rows x 9 columns]

# %%
# Perform a linear regression on Northern Hemisphere - Temperature (F) vs. Latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(northern_cities ["Latitude"], northern_cities ["Max Temp"])

# Get regression values
regress_values = northern_cities ["Latitude"] * slope + intercept
# print(regress_values)

# %%
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# Out:
# y = -0.51x +91.88

# %%
# Create Plot
plt.scatter(northern_cities ["Latitude"],northern_cities ["Max Temp"])
plt.plot(northern_cities ["Latitude"],regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title('Northern Hemisphere - Temperature (F) vs. Latitude')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.4461886014017391

# %%
# Perform a linear regression on Southern Hemisphere - Temperature (F) vs. Latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(southern_cities ["Latitude"], southern_cities ["Max Temp"])

# Get regression values
s_regress_values = southern_cities ["Latitude"] * slope + intercept
# print(regress_values)

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create Plot
plt.scatter(southern_cities ["Latitude"],southern_cities ["Max Temp"])
plt.plot(southern_cities ["Latitude"],s_regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title('Southern Hemisphere - Temperature (F) vs. Latitude')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.76x +80.3
# The r-squared is: 0.5081057001636315

# %%
# Perform a linear regression on Northern Hemisphere - Humidity (%) vs. Latitude

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(northern_cities ["Latitude"], northern_cities ["Humidity"])

# Get regression values
n_hum_regress_values = northern_cities ["Latitude"] * slope + intercept
# print(regress_values)

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create Plot
plt.scatter(northern_cities ["Latitude"],northern_cities ["Humidity"])
plt.plot(northern_cities ["Latitude"],n_hum_regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = -0.01x +67.68
# The r-squared is: 2.8206155535017232e-05

# %%
# Perform a linear regression on Southern Hemisphere - Humidity (%) vs. Latitude

(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(southern_cities ["Latitude"], southern_cities ["Humidity"])

# Get regression values
s_hum_regress_values = southern_cities ["Latitude"] * slope + intercept
# print(regress_values)

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create Plot
plt.scatter(southern_cities ["Latitude"],southern_cities ["Humidity"])
plt.plot(southern_cities ["Latitude"],s_hum_regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude')
plt.annotate(line_eq,(20,15),fontsize=15,color="green")

# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = -0.11x +71.89
# The r-squared is: 0.004829959990241879
