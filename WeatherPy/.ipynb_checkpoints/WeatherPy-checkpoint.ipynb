# %%
# !pip install git+git://github.com/geopandas/geopandas.git --quiet
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /opt/anaconda3/envs/PythonData/lib/python3.7/site-packages (from citipy) (0.16)

# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
import numpy as np
from scipy import stats
from config import api_key
from random import uniform

# to find a city based on longitude and latitude
from citipy import citipy

# %%
# x, y = uniform(-180,180), uniform(-90, 90)

# def newpoint():
#    return uniform(-180,180), uniform(-90, 90)

# the_points = (newpoint() for x in range(15))
# for points in the_points:
# #    print(point)

# %%
# Create a set of random lat and lng combinations
lat_lngs =[]
lats = np.random.uniform(low=-90.000, high=90.000, size=1300)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1300)
lat_lngs = zip(lats, lngs)
# print(*lat_lngs)

# %%
# create a list to hold the cities
cities =[]

# Identify nearest city for each lat, lng combination
# for point in points:
#     city = citipy.nearest_city(point[0], point[1]).city_name
    
for points in lat_lngs:
    city = citipy.nearest_city(points[0], points[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
#     print(cities) 
# check the city count to make sure we have at least 500
len(cities)
#print(cities)
# Out:
# 532

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"

# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="
query_url

# set up lists to hold reponse info and city counter
city_weather = []
city_cnt = 1

print(f"There are {len(cities)}")
for city in cities:
    print(f"City number {city_cnt} is {city}")
    try:
        response = requests.get(query_url + city).json()
        city_lat = response['coord']['lat']
        city_mtemp = response['main']['temp_max']
        city_humidity = response['main']['humidity']
        city_cloudiness = response['clouds']['all']
        city_wspeed = response['wind']['speed']
        city_weather.append({"city":city,
                      "Latitude":city_lat,
                      "Max Temp":city_mtemp,
                      "Humidity":city_humidity,
                      "Cloudiness":city_cloudiness,
                      "Wind Speed":city_wspeed,
                      })
        print(f"{city} processed successfully")
        city_cnt +=1
        
    except KeyError:
        print(f'No data for {city}. Skipping {city}')
        city_cnt +=1
# Out:
# There are 532
# City number 1 is hithadhoo
# hithadhoo processed successfully
# City number 2 is tual
# tual processed successfully
# City number 3 is busselton
# busselton processed successfully
# City number 4 is podgorica
# podgorica processed successfully
# City number 5 is dingle
# dingle processed successfully
# City number 6 is ushuaia
# ushuaia processed successfully
# City number 7 is yar-sale
# yar-sale processed successfully
# City number 8 is hasaki
# hasaki processed successfully
# City number 9 is bluff
# bluff processed successfully
# City number 10 is grand river south east
# No data for grand river south east. Skipping grand river south east
# City number 11 is luba
# luba processed successfully
# City number 12 is albany
# albany processed successfully
# City number 13 is decin
# decin processed successfully
# City number 14 is nha trang
# nha trang processed successfully
# City number 15 is hobart
# hobart processed successfully
# City number 16 is port alfred
# port alfred processed successfully
# City number 17 is guerrero negro
# guerrero negro processed successfully
# City number 18 is aviles
# aviles processed successfully
# City number 19 is carnarvon
# carnarvon processed successfully
# City number 20 is changping
# changping processed successfully
# City number 21 is huarmey
# huarmey processed successfully
# City number 22 is caravelas
# caravelas processed successfully
# City number 23 is noumea
# noumea processed successfully
# City number 24 is butaritari
# butaritari processed successfully
# City number 25 is pangody
# pangody processed successfully
# City number 26 is jijiga
# jijiga processed successfully
# City number 27 is rikitea
# rikitea processed successfully
# City number 28 is rocha
# rocha processed successfully
# City number 29 is cape town
# cape town processed successfully
# City number 30 is punta arenas
# punta arenas processed successfully
# City number 31 is katsuura
# katsuura processed successfully
# City number 32 is torbay
# torbay processed successfully
# City number 33 is avarua
# avarua processed successfully
# City number 34 is pacific grove
# pacific grove processed successfully
# City number 35 is amderma
# No data for amderma. Skipping amderma
# City number 36 is jamestown
# jamestown processed successfully
# City number 37 is bonthe
# bonthe processed successfully
# City number 38 is mataura
# mataura processed successfully
# City number 39 is yelan
# yelan processed successfully
# City number 40 is tsihombe
# No data for tsihombe. Skipping tsihombe
# City number 41 is srednekolymsk
# srednekolymsk processed successfully
# City number 42 is hermanus
# hermanus processed successfully
# City number 43 is kapaa
# kapaa processed successfully
# City number 44 is harper
# harper processed successfully
# City number 45 is ust-kulom
# ust-kulom processed successfully
# City number 46 is kruisfontein
# kruisfontein processed successfully
# City number 47 is correntina
# correntina processed successfully
# City number 48 is mar del plata
# mar del plata processed successfully
# City number 49 is arraial do cabo
# arraial do cabo processed successfully
# City number 50 is sorong
# sorong processed successfully
# City number 51 is belushya guba
# No data for belushya guba. Skipping belushya guba
# City number 52 is pirovskoye
# pirovskoye processed successfully
# City number 53 is pimentel
# pimentel processed successfully
# City number 54 is saint-philippe
# saint-philippe processed successfully
# City number 55 is pisco
# pisco processed successfully
# City number 56 is upernavik
# upernavik processed successfully
# City number 57 is kailua
# kailua processed successfully
# City number 58 is new norfolk
# new norfolk processed successfully
# City number 59 is cuamba
# cuamba processed successfully
# City number 60 is nikolskoye
# nikolskoye processed successfully
# City number 61 is pevek
# pevek processed successfully
# City number 62 is thompson
# thompson processed successfully
# City number 63 is taolanaro
# No data for taolanaro. Skipping taolanaro
# City number 64 is batasan
# batasan processed successfully
# City number 65 is airai
# airai processed successfully
# City number 66 is aripuana
# aripuana processed successfully
# City number 67 is kaduy
# kaduy processed successfully
# City number 68 is ponta do sol
# ponta do sol processed successfully
# City number 69 is beech grove
# beech grove processed successfully
# City number 70 is vardo
# vardo processed successfully
# City number 71 is padang
# padang processed successfully
# City number 72 is taoudenni
# taoudenni processed successfully
# City number 73 is bredasdorp
# bredasdorp processed successfully
# City number 74 is santa cruz do capibaribe
# santa cruz do capibaribe processed successfully
# City number 75 is iranshahr
# iranshahr processed successfully
# City number 76 is grindavik
# grindavik processed successfully
# City number 77 is mollendo
# mollendo processed successfully
# City number 78 is bengkulu
# bengkulu processed successfully
# City number 79 is viligili
# No data for viligili. Skipping viligili
# City number 80 is sault sainte marie
# sault sainte marie processed successfully
# City number 81 is geraldton
# geraldton processed successfully
# City number 82 is sentyabrskiy
# No data for sentyabrskiy. Skipping sentyabrskiy
# City number 83 is tiksi
# tiksi processed successfully
# City number 84 is tezu
# tezu processed successfully
# City number 85 is sinnamary
# sinnamary processed successfully
# City number 86 is manggar
# manggar processed successfully
# City number 87 is tungor
# tungor processed successfully
# City number 88 is chokurdakh
# chokurdakh processed successfully
# City number 89 is morros
# morros processed successfully
# City number 90 is mukhen
# mukhen processed successfully
# City number 91 is longyearbyen
# longyearbyen processed successfully
# City number 92 is krasnoarmeysk
# krasnoarmeysk processed successfully
# City number 93 is kadoma
# kadoma processed successfully
# City number 94 is saint george
# saint george processed successfully
# City number 95 is yellowknife
# yellowknife processed successfully
# City number 96 is poronaysk
# poronaysk processed successfully
# City number 97 is bilma
# bilma processed successfully
# City number 98 is marseille
# marseille processed successfully
# City number 99 is rawson
# rawson processed successfully
# City number 100 is seagoville
# seagoville processed successfully
# City number 101 is cheremnoye
# cheremnoye processed successfully
# City number 102 is lavrentiya
# lavrentiya processed successfully
# City number 103 is bethel
# bethel processed successfully
# City number 104 is kaitangata
# kaitangata processed successfully
# City number 105 is saint-joseph
# saint-joseph processed successfully
# City number 106 is viedma
# viedma processed successfully
# City number 107 is hilo
# hilo processed successfully
# City number 108 is malakal
# malakal processed successfully
# City number 109 is tumannyy
# No data for tumannyy. Skipping tumannyy
# City number 110 is vila franca do campo
# vila franca do campo processed successfully
# City number 111 is doba
# doba processed successfully
# City number 112 is ternate
# ternate processed successfully
# City number 113 is souillac
# souillac processed successfully
# City number 114 is yemelyanovo
# yemelyanovo processed successfully
# City number 115 is provideniya
# provideniya processed successfully
# City number 116 is samusu
# No data for samusu. Skipping samusu
# City number 117 is kurilsk
# kurilsk processed successfully
# City number 118 is ust-kamchatsk
# No data for ust-kamchatsk. Skipping ust-kamchatsk
# City number 119 is zhuhai
# zhuhai processed successfully
# City number 120 is mecca
# mecca processed successfully
# City number 121 is ayagoz
# ayagoz processed successfully
# City number 122 is ho
# No data for ho. Skipping ho
# City number 123 is fortuna
# fortuna processed successfully
# City number 124 is cagayan de tawi-tawi
# No data for cagayan de tawi-tawi. Skipping cagayan de tawi-tawi
# City number 125 is guasdualito
# guasdualito processed successfully
# City number 126 is buraydah
# buraydah processed successfully
# City number 127 is luderitz
# luderitz processed successfully
# City number 128 is narsaq
# narsaq processed successfully
# City number 129 is harrisburg
# harrisburg processed successfully
# City number 130 is bowen
# bowen processed successfully
# City number 131 is atambua
# atambua processed successfully
# City number 132 is fairbanks
# fairbanks processed successfully
# City number 133 is tuktoyaktuk
# tuktoyaktuk processed successfully
# City number 134 is shihezi
# shihezi processed successfully
# City number 135 is tommot
# tommot processed successfully
# City number 136 is tasbuget
# No data for tasbuget. Skipping tasbuget
# City number 137 is garissa
# garissa processed successfully
# City number 138 is nizhneyansk
# No data for nizhneyansk. Skipping nizhneyansk
# City number 139 is toliary
# No data for toliary. Skipping toliary
# City number 140 is georgiyevka
# georgiyevka processed successfully
# City number 141 is recklinghausen
# recklinghausen processed successfully
# City number 142 is bambous virieux
# bambous virieux processed successfully
# City number 143 is castro
# castro processed successfully
# City number 144 is khatanga
# khatanga processed successfully
# City number 145 is pingliang
# pingliang processed successfully
# City number 146 is karasjok
# karasjok processed successfully
# City number 147 is barentsburg
# No data for barentsburg. Skipping barentsburg
# City number 148 is cayenne
# cayenne processed successfully
# City number 149 is thinadhoo
# thinadhoo processed successfully
# City number 150 is gizo
# gizo processed successfully
# City number 151 is tawkar
# No data for tawkar. Skipping tawkar
# City number 152 is puerto ayora
# puerto ayora processed successfully
# City number 153 is alotau
# No data for alotau. Skipping alotau
# City number 154 is morant bay
# morant bay processed successfully
# City number 155 is deputatskiy
# deputatskiy processed successfully
# City number 156 is faanui
# faanui processed successfully
# City number 157 is lata
# lata processed successfully
# City number 158 is attawapiskat
# No data for attawapiskat. Skipping attawapiskat
# City number 159 is manbij
# manbij processed successfully
# City number 160 is homer
# homer processed successfully
# City number 161 is saleaula
# No data for saleaula. Skipping saleaula
# City number 162 is carutapera
# carutapera processed successfully
# City number 163 is barrow
# barrow processed successfully
# City number 164 is wangkui
# wangkui processed successfully
# City number 165 is zaysan
# zaysan processed successfully
# City number 166 is nouadhibou
# nouadhibou processed successfully
# City number 167 is ahmadpur sial
# ahmadpur sial processed successfully
# City number 168 is winneba
# winneba processed successfully
# City number 169 is kulhudhuffushi
# kulhudhuffushi processed successfully
# City number 170 is fare
# fare processed successfully
# City number 171 is ancud
# ancud processed successfully
# City number 172 is port augusta
# port augusta processed successfully
# City number 173 is tarko-sale
# tarko-sale processed successfully
# City number 174 is nanortalik
# nanortalik processed successfully
# City number 175 is leh
# leh processed successfully
# City number 176 is hamilton
# hamilton processed successfully
# City number 177 is weiser
# weiser processed successfully
# City number 178 is mahebourg
# mahebourg processed successfully
# City number 179 is esperance
# esperance processed successfully
# City number 180 is rockport
# rockport processed successfully
# City number 181 is lebu
# lebu processed successfully
# City number 182 is halifax
# halifax processed successfully
# City number 183 is north bend
# north bend processed successfully
# City number 184 is itoman
# itoman processed successfully
# City number 185 is quang ngai
# quang ngai processed successfully
# City number 186 is tasiilaq
# tasiilaq processed successfully
# City number 187 is emerald
# emerald processed successfully
# City number 188 is ribeira grande
# ribeira grande processed successfully
# City number 189 is roma
# roma processed successfully
# City number 190 is port hardy
# port hardy processed successfully
# City number 191 is pyinmana
# pyinmana processed successfully
# City number 192 is najran
# najran processed successfully
# City number 193 is ilulissat
# ilulissat processed successfully
# City number 194 is luwuk
# luwuk processed successfully
# City number 195 is cherskiy
# cherskiy processed successfully
# City number 196 is hami
# hami processed successfully
# City number 197 is puno
# puno processed successfully
# City number 198 is kudahuvadhoo
# kudahuvadhoo processed successfully
# City number 199 is pangnirtung
# pangnirtung processed successfully
# City number 200 is port blair
# port blair processed successfully
# City number 201 is anadyr
# anadyr processed successfully
# City number 202 is nantucket
# nantucket processed successfully
# City number 203 is porto seguro
# porto seguro processed successfully
# City number 204 is husavik
# husavik processed successfully
# City number 205 is snasa
# snasa processed successfully
# City number 206 is douglas
# douglas processed successfully
# City number 207 is alofi
# alofi processed successfully
# City number 208 is kemin
# kemin processed successfully
# City number 209 is scarborough
# scarborough processed successfully
# City number 210 is marcona
# No data for marcona. Skipping marcona
# City number 211 is danville
# danville processed successfully
# City number 212 is vaini
# vaini processed successfully
# City number 213 is minas
# minas processed successfully
# City number 214 is saly
# saly processed successfully
# City number 215 is kahului
# kahului processed successfully
# City number 216 is sinegorye
# sinegorye processed successfully
# City number 217 is victor harbor
# victor harbor processed successfully
# City number 218 is turiacu
# turiacu processed successfully
# City number 219 is surt
# surt processed successfully
# City number 220 is atuona
# atuona processed successfully
# City number 221 is sungairaya
# sungairaya processed successfully
# City number 222 is dikson
# dikson processed successfully
# City number 223 is argelia
# argelia processed successfully
# City number 224 is ahipara
# ahipara processed successfully
# City number 225 is illoqqortoormiut
# No data for illoqqortoormiut. Skipping illoqqortoormiut
# City number 226 is longyan
# longyan processed successfully
# City number 227 is kavieng
# kavieng processed successfully
# City number 228 is jadu
# jadu processed successfully
# City number 229 is liverpool
# liverpool processed successfully
# City number 230 is kuche
# No data for kuche. Skipping kuche
# City number 231 is savannah bight
# savannah bight processed successfully
# City number 232 is sao filipe
# sao filipe processed successfully
# City number 233 is victoria
# victoria processed successfully
# City number 234 is isangel
# isangel processed successfully
# City number 235 is tuatapere
# tuatapere processed successfully
# City number 236 is te anau
# te anau processed successfully
# City number 237 is san patricio
# san patricio processed successfully
# City number 238 is praia
# praia processed successfully
# City number 239 is beyneu
# beyneu processed successfully
# City number 240 is samarai
# samarai processed successfully
# City number 241 is beringovskiy
# beringovskiy processed successfully
# City number 242 is olafsvik
# olafsvik processed successfully
# City number 243 is ostrovnoy
# ostrovnoy processed successfully
# City number 244 is shimoda
# shimoda processed successfully
# City number 245 is marzuq
# marzuq processed successfully
# City number 246 is shubarshi
# shubarshi processed successfully
# City number 247 is cardston
# cardston processed successfully
# City number 248 is panjwin
# No data for panjwin. Skipping panjwin
# City number 249 is ilhabela
# ilhabela processed successfully
# City number 250 is sibolga
# sibolga processed successfully
# City number 251 is ust-nera
# ust-nera processed successfully
# City number 252 is calbuco
# calbuco processed successfully
# City number 253 is norman wells
# norman wells processed successfully
# City number 254 is goderich
# goderich processed successfully
# City number 255 is leningradskiy
# leningradskiy processed successfully
# City number 256 is tigil
# tigil processed successfully
# City number 257 is constitucion
# constitucion processed successfully
# City number 258 is altay
# altay processed successfully
# City number 259 is luanda
# luanda processed successfully
# City number 260 is korla
# korla processed successfully
# City number 261 is tongliao
# tongliao processed successfully
# City number 262 is kismayo
# kismayo processed successfully
# City number 263 is the valley
# the valley processed successfully
# City number 264 is nizhniy kuranakh
# nizhniy kuranakh processed successfully
# City number 265 is guarapari
# guarapari processed successfully
# City number 266 is fort saint john
# No data for fort saint john. Skipping fort saint john
# City number 267 is saskylakh
# saskylakh processed successfully
# City number 268 is shipunovo
# shipunovo processed successfully
# City number 269 is georgetown
# georgetown processed successfully
# City number 270 is ugoofaaru
# ugoofaaru processed successfully
# City number 271 is nipani
# nipani processed successfully
# City number 272 is atsiki
# No data for atsiki. Skipping atsiki
# City number 273 is muroto
# muroto processed successfully
# City number 274 is avera
# avera processed successfully
# City number 275 is mhango
# mhango processed successfully
# City number 276 is havoysund
# havoysund processed successfully
# City number 277 is touros
# touros processed successfully
# City number 278 is qaanaaq
# qaanaaq processed successfully
# City number 279 is yaring
# yaring processed successfully
# City number 280 is arrifes
# arrifes processed successfully
# City number 281 is sri aman
# sri aman processed successfully
# City number 282 is broken hill
# broken hill processed successfully
# City number 283 is port elizabeth
# port elizabeth processed successfully
# City number 284 is aquiraz
# aquiraz processed successfully
# City number 285 is poum
# poum processed successfully
# City number 286 is kashan
# kashan processed successfully
# City number 287 is mayumba
# mayumba processed successfully
# City number 288 is dunhua
# dunhua processed successfully
# City number 289 is suntar
# suntar processed successfully
# City number 290 is lagoa
# lagoa processed successfully
# City number 291 is aksarka
# aksarka processed successfully
# City number 292 is senneterre
# senneterre processed successfully
# City number 293 is barmer
# barmer processed successfully
# City number 294 is key west
# key west processed successfully
# City number 295 is sitka
# sitka processed successfully
# City number 296 is port hedland
# port hedland processed successfully
# City number 297 is sao joao da barra
# sao joao da barra processed successfully
# City number 298 is vila velha
# vila velha processed successfully
# City number 299 is mehamn
# mehamn processed successfully
# City number 300 is bitung
# bitung processed successfully
# City number 301 is gobabis
# gobabis processed successfully
# City number 302 is henties bay
# henties bay processed successfully
# City number 303 is margate
# margate processed successfully
# City number 304 is gashua
# gashua processed successfully
# City number 305 is anzio
# anzio processed successfully
# City number 306 is gat
# gat processed successfully
# City number 307 is nuevo progreso
# nuevo progreso processed successfully
# City number 308 is sakakah
# sakakah processed successfully
# City number 309 is waverly
# waverly processed successfully
# City number 310 is scottsburgh
# No data for scottsburgh. Skipping scottsburgh
# City number 311 is codrington
# codrington processed successfully
# City number 312 is lahad datu
# lahad datu processed successfully
# City number 313 is flinders
# flinders processed successfully
# City number 314 is ballina
# ballina processed successfully
# City number 315 is ribas do rio pardo
# ribas do rio pardo processed successfully
# City number 316 is lakota
# lakota processed successfully
# City number 317 is burica
# No data for burica. Skipping burica
# City number 318 is owerri
# owerri processed successfully
# City number 319 is watsa
# watsa processed successfully
# City number 320 is kolyubakino
# kolyubakino processed successfully
# City number 321 is sisimiut
# sisimiut processed successfully
# City number 322 is jalu
# jalu processed successfully
# City number 323 is ambunti
# ambunti processed successfully
# City number 324 is lorengau
# lorengau processed successfully
# City number 325 is pampa
# pampa processed successfully
# City number 326 is waitara
# waitara processed successfully
# City number 327 is talara
# talara processed successfully
# City number 328 is burns lake
# burns lake processed successfully
# City number 329 is namibe
# namibe processed successfully
# City number 330 is businga
# businga processed successfully
# City number 331 is broome
# broome processed successfully
# City number 332 is santa maria del oro
# santa maria del oro processed successfully
# City number 333 is bastia
# bastia processed successfully
# City number 334 is severo-kurilsk
# severo-kurilsk processed successfully
# City number 335 is waipawa
# waipawa processed successfully
# City number 336 is kodiak
# kodiak processed successfully
# City number 337 is kuusamo
# kuusamo processed successfully
# City number 338 is port macquarie
# port macquarie processed successfully
# City number 339 is eston
# eston processed successfully
# City number 340 is east london
# east london processed successfully
# City number 341 is canakkale
# canakkale processed successfully
# City number 342 is kamenskoye
# No data for kamenskoye. Skipping kamenskoye
# City number 343 is kumbo
# kumbo processed successfully
# City number 344 is qrendi
# qrendi processed successfully
# City number 345 is vaitupu
# No data for vaitupu. Skipping vaitupu
# City number 346 is galesong
# galesong processed successfully
# City number 347 is muscat
# muscat processed successfully
# City number 348 is chuy
# chuy processed successfully
# City number 349 is mullaitivu
# No data for mullaitivu. Skipping mullaitivu
# City number 350 is namatanai
# namatanai processed successfully
# City number 351 is la ronge
# la ronge processed successfully
# City number 352 is cabo san lucas
# cabo san lucas processed successfully
# City number 353 is neuquen
# neuquen processed successfully
# City number 354 is skjervoy
# skjervoy processed successfully
# City number 355 is manokwari
# manokwari processed successfully
# City number 356 is athabasca
# athabasca processed successfully
# City number 357 is kundiawa
# kundiawa processed successfully
# City number 358 is santiago del estero
# santiago del estero processed successfully
# City number 359 is kusye-aleksandrovskiy
# No data for kusye-aleksandrovskiy. Skipping kusye-aleksandrovskiy
# City number 360 is thisted
# thisted processed successfully
# City number 361 is sioux lookout
# sioux lookout processed successfully
# City number 362 is buala
# buala processed successfully
# City number 363 is esmeraldas
# esmeraldas processed successfully
# City number 364 is camana
# camana processed successfully
# City number 365 is coihaique
# coihaique processed successfully
# City number 366 is ucluelet
# ucluelet processed successfully
# City number 367 is coxim
# coxim processed successfully
# City number 368 is dakar
# dakar processed successfully
# City number 369 is staryy nadym
# staryy nadym processed successfully
# City number 370 is boende
# boende processed successfully
# City number 371 is camacha
# camacha processed successfully
# City number 372 is atasu
# atasu processed successfully
# City number 373 is teya
# teya processed successfully
# City number 374 is necochea
# necochea processed successfully
# City number 375 is mayo
# mayo processed successfully
# City number 376 is seoul
# seoul processed successfully
# City number 377 is pustoshka
# pustoshka processed successfully
# City number 378 is novosineglazovskiy
# novosineglazovskiy processed successfully
# City number 379 is oktyabrskoye
# oktyabrskoye processed successfully
# City number 380 is raudeberg
# raudeberg processed successfully
# City number 381 is aleksandrovskiy zavod
# aleksandrovskiy zavod processed successfully
# City number 382 is safford
# safford processed successfully
# City number 383 is nelson bay
# nelson bay processed successfully
# City number 384 is angoche
# angoche processed successfully
# City number 385 is pitimbu
# pitimbu processed successfully
# City number 386 is malvern
# malvern processed successfully
# City number 387 is wattegama
# wattegama processed successfully
# City number 388 is marquette
# marquette processed successfully
# City number 389 is lahij
# lahij processed successfully
# City number 390 is grand gaube
# grand gaube processed successfully
# City number 391 is nemuro
# nemuro processed successfully
# City number 392 is gigmoto
# gigmoto processed successfully
# City number 393 is guiratinga
# guiratinga processed successfully
# City number 394 is solovetskiy
# No data for solovetskiy. Skipping solovetskiy
# City number 395 is zhigansk
# zhigansk processed successfully
# City number 396 is marrakesh
# marrakesh processed successfully
# City number 397 is hofn
# hofn processed successfully
# City number 398 is belyy yar
# belyy yar processed successfully
# City number 399 is tessalit
# tessalit processed successfully
# City number 400 is furano
# furano processed successfully
# City number 401 is roald
# roald processed successfully
# City number 402 is varhaug
# varhaug processed successfully
# City number 403 is katsiveli
# No data for katsiveli. Skipping katsiveli
# City number 404 is qidong
# qidong processed successfully
# City number 405 is wajima
# wajima processed successfully
# City number 406 is oistins
# oistins processed successfully
# City number 407 is boca do acre
# boca do acre processed successfully
# City number 408 is alice springs
# alice springs processed successfully
# City number 409 is effingham
# effingham processed successfully
# City number 410 is talnakh
# talnakh processed successfully
# City number 411 is tarudant
# No data for tarudant. Skipping tarudant
# City number 412 is miri
# miri processed successfully
# City number 413 is meyungs
# No data for meyungs. Skipping meyungs
# City number 414 is tilichiki
# tilichiki processed successfully
# City number 415 is havelock
# havelock processed successfully
# City number 416 is rantepao
# rantepao processed successfully
# City number 417 is chapais
# chapais processed successfully
# City number 418 is virpur
# virpur processed successfully
# City number 419 is formosa
# formosa processed successfully
# City number 420 is bridgetown
# bridgetown processed successfully
# City number 421 is bairiki
# bairiki processed successfully
# City number 422 is ambulu
# ambulu processed successfully
# City number 423 is okha
# okha processed successfully
# City number 424 is srandakan
# srandakan processed successfully
# City number 425 is handan
# handan processed successfully
# City number 426 is cozumel
# cozumel processed successfully
# City number 427 is weligama
# weligama processed successfully
# City number 428 is sataua
# No data for sataua. Skipping sataua
# City number 429 is dovers
# dovers processed successfully
# City number 430 is laguna
# laguna processed successfully
# City number 431 is atar
# atar processed successfully
# City number 432 is carolina
# carolina processed successfully
# City number 433 is sobolevo
# sobolevo processed successfully
# City number 434 is ngukurr
# No data for ngukurr. Skipping ngukurr
# City number 435 is richards bay
# richards bay processed successfully
# City number 436 is pierrelatte
# pierrelatte processed successfully
# City number 437 is jarjis
# No data for jarjis. Skipping jarjis
# City number 438 is kavaratti
# kavaratti processed successfully
# City number 439 is upata
# upata processed successfully
# City number 440 is lolua
# No data for lolua. Skipping lolua
# City number 441 is caluquembe
# caluquembe processed successfully
# City number 442 is tiarei
# tiarei processed successfully
# City number 443 is biharamulo
# biharamulo processed successfully
# City number 444 is indian head
# indian head processed successfully
# City number 445 is gushikawa
# gushikawa processed successfully
# City number 446 is yinchuan
# yinchuan processed successfully
# City number 447 is candido mendes
# candido mendes processed successfully
# City number 448 is meiganga
# meiganga processed successfully
# City number 449 is santa isabel
# santa isabel processed successfully
# City number 450 is neyshabur
# neyshabur processed successfully
# City number 451 is of
# No data for of. Skipping of
# City number 452 is iquique
# iquique processed successfully
# City number 453 is ughelli
# ughelli processed successfully
# City number 454 is nabire
# nabire processed successfully
# City number 455 is russell
# russell processed successfully
# City number 456 is amurzet
# amurzet processed successfully
# City number 457 is lazaro cardenas
# lazaro cardenas processed successfully
# City number 458 is wanning
# wanning processed successfully
# City number 459 is hambantota
# hambantota processed successfully
# City number 460 is grants pass
# grants pass processed successfully
# City number 461 is linxia
# linxia processed successfully
# City number 462 is kerema
# kerema processed successfully
# City number 463 is flin flon
# flin flon processed successfully
# City number 464 is fairfield
# fairfield processed successfully
# City number 465 is ippy
# ippy processed successfully
# City number 466 is dukat
# dukat processed successfully
# City number 467 is itarema
# itarema processed successfully
# City number 468 is havre-saint-pierre
# havre-saint-pierre processed successfully
# City number 469 is aleksandrov gay
# aleksandrov gay processed successfully
# City number 470 is anzoategui
# anzoategui processed successfully
# City number 471 is novyy urengoy
# novyy urengoy processed successfully
# City number 472 is biak
# biak processed successfully
# City number 473 is sunnyside
# sunnyside processed successfully
# City number 474 is jos
# jos processed successfully
# City number 475 is hay river
# hay river processed successfully
# City number 476 is erdenet
# erdenet processed successfully
# City number 477 is mount isa
# mount isa processed successfully
# City number 478 is dwarka
# dwarka processed successfully
# City number 479 is miandrivazo
# miandrivazo processed successfully
# City number 480 is pochutla
# pochutla processed successfully
# City number 481 is palana
# palana processed successfully
# City number 482 is biltine
# biltine processed successfully
# City number 483 is stawell
# stawell processed successfully
# City number 484 is fergus falls
# fergus falls processed successfully
# City number 485 is sur
# sur processed successfully
# City number 486 is ozieri
# ozieri processed successfully
# City number 487 is zhanaozen
# zhanaozen processed successfully
# City number 488 is kapoeta
# kapoeta processed successfully
# City number 489 is isetskoye
# isetskoye processed successfully
# City number 490 is ziro
# ziro processed successfully
# City number 491 is mielec
# mielec processed successfully
# City number 492 is luancheng
# luancheng processed successfully
# City number 493 is puerto escondido
# puerto escondido processed successfully
# City number 494 is san luis
# san luis processed successfully
# City number 495 is sayan
# sayan processed successfully
# City number 496 is mareeba
# mareeba processed successfully
# City number 497 is micheweni
# micheweni processed successfully
# City number 498 is muravlenko
# muravlenko processed successfully
# City number 499 is lasa
# lasa processed successfully
# City number 500 is yantal
# yantal processed successfully
# City number 501 is tura
# tura processed successfully
# City number 502 is coquimbo
# coquimbo processed successfully
# City number 503 is carlagan
# carlagan processed successfully
# City number 504 is kuhestan
# No data for kuhestan. Skipping kuhestan
# City number 505 is lillesand
# lillesand processed successfully
# City number 506 is krasna
# krasna processed successfully
# City number 507 is turkmenabat
# turkmenabat processed successfully
# City number 508 is beloha
# beloha processed successfully
# City number 509 is sabang
# sabang processed successfully
# City number 510 is bubaque
# bubaque processed successfully
# City number 511 is hirara
# hirara processed successfully
# City number 512 is stolin
# stolin processed successfully
# City number 513 is chabahar
# chabahar processed successfully
# City number 514 is warqla
# No data for warqla. Skipping warqla
# City number 515 is sesheke
# sesheke processed successfully
# City number 516 is dzhusaly
# No data for dzhusaly. Skipping dzhusaly
# City number 517 is gamba
# gamba processed successfully
# City number 518 is ulladulla
# ulladulla processed successfully
# City number 519 is catalao
# catalao processed successfully
# City number 520 is poya
# poya processed successfully
# City number 521 is resistencia
# resistencia processed successfully
# City number 522 is aklavik
# aklavik processed successfully
# City number 523 is manyana
# manyana processed successfully
# City number 524 is wanxian
# wanxian processed successfully
# City number 525 is quatre cocos
# quatre cocos processed successfully
# City number 526 is mys shmidta
# No data for mys shmidta. Skipping mys shmidta
# City number 527 is pangai
# pangai processed successfully
# City number 528 is tazovskiy
# tazovskiy processed successfully
# City number 529 is nakhon si thammarat
# nakhon si thammarat processed successfully
# City number 530 is meulaboh
# meulaboh processed successfully
# City number 531 is shaki
# shaki processed successfully
# City number 532 is strezhevoy
# strezhevoy processed successfully

# %%
#create a dataframe for plotting
city_weather_df = pd.DataFrame(city_weather)

city_weather_df
# Out:
#                     city  Latitude  Max Temp  Humidity  Cloudiness  Wind Speed
# 0              hithadhoo     -0.60     84.74        64         100        5.99
# 1                   tual     -5.67     79.66        85           5       16.46
# 2              busselton    -33.65     55.99        94          98        5.01
# 3              podgorica     42.44     82.40        39          77       11.41
# 4                 dingle     11.00     88.59        63          35        7.87
# ..                   ...       ...       ...       ...         ...         ...
# 482            tazovskiy     67.47     61.23        57           0       14.99
# 483  nakhon si thammarat      8.43     95.00        53          20        3.36
# 484             meulaboh      4.14     86.58        69          91        5.12
# 485                shaki     41.08     84.20        37           0        2.24
# 486           strezhevoy     60.73     77.00        44          98        4.47
#
# [487 rows x 6 columns]

# %%
# Temperature (F) vs. Latitude Plot
plt.scatter(city_weather_df ["Latitude"], city_weather_df ["Max Temp"], marker="o", s=10)

# plot labels, x and y
plt.title("Temperature (F) vs. Latitude")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# Save the figure
plt.savefig("Plots/Temp_vs_Latitude.png")

# %%
# The data is showing that the temperature trends warmer in the cities in the latitudes between 0 and 40.

# %%
# Humidity (%) vs. Latitude Plot
plt.scatter(city_weather_df ["Latitude"], city_weather_df ["Humidity"], marker="o", s=10)

# plot labels, x and y
plt.title("Humidity (%) vs. Latitude Plot")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# Save the figure
plt.savefig("Plots/Humidity_vs_Latitude.png")

# %%
# This data shows that there can be high humidity in all latitudes

# %%
# Cloudiness (%) vs. Latitude Plot
plt.scatter(city_weather_df ["Latitude"], city_weather_df ["Cloudiness"], marker="o", s=10)

# plot labels, x and y
plt.title("Cloudiness (%) vs. Latitude Plot")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# Save the figure
plt.savefig("Plots/Cloudiness_vs_Latitude.png")

# %%
# This data shows that cloudiness varies in all latitudes

# %%
# Wind Speed (mph) vs. Latitude
plt.scatter(city_weather_df ["Latitude"], city_weather_df ["Wind Speed"], marker="o", s=10)

# plot labels, x and y
plt.title("Wind Speed (mph) vs. Latitude Plot")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Show plot
plt.show()

# Save the figure
plt.savefig("Plots/Wind_vs_Latitude.png")

# %%
# This data shows that winds are mostly below 10 mph in all latitudes

# %%
# Save a CSV of all retrieved data
city_weather_df.to_csv("city_weather_data.csv")

# %%
# Perform a linear regression on Northern Hemisphere - Temperature (F) vs. Latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(city_weather_df ["Latitude"], city_weather_df ["Max Temp"])

# Get regression values
regress_values = city_weather_df ["Latitude"] * slope + intercept
print(regress_values)
# Out:
# 0      69.295466
# 1      69.214871
# 2      68.770089
# 3      69.979647
# 4      69.479864
#          ...
# 482    70.377535
# 483    69.439010
# 484    69.370815
# 485    69.958028
# 486    70.270393
# Name: Latitude, Length: 487, dtype: float64

# %%
# Seperate the northern and southern Hemisphere
northern_cities = city_weather_df[(city_weather_df["Latitude"] >= 0)]
northern_cities
# Out:
#                     city  Latitude  Max Temp  Humidity  Cloudiness  Wind Speed
# 3              podgorica     42.44     82.40        39          77       11.41
# 4                 dingle     11.00     88.59        63          35        7.87
# 6               yar-sale     66.83     75.38        45          63        8.70
# 7                 hasaki     35.73     81.00        83          75       14.99
# 9                   luba      3.46     75.20       100          75        6.93
# ..                   ...       ...       ...       ...         ...         ...
# 482            tazovskiy     67.47     61.23        57           0       14.99
# 483  nakhon si thammarat      8.43     95.00        53          20        3.36
# 484             meulaboh      4.14     86.58        69          91        5.12
# 485                shaki     41.08     84.20        37           0        2.24
# 486           strezhevoy     60.73     77.00        44          98        4.47
#
# [328 rows x 6 columns]

# %%
southern_cities = city_weather_df[(city_weather_df["Latitude"] < 0)]
southern_cities
# Out:
#              city  Latitude  Max Temp  Humidity  Cloudiness  Wind Speed
# 0       hithadhoo     -0.60     84.74        64         100        5.99
# 1            tual     -5.67     79.66        85           5       16.46
# 2       busselton    -33.65     55.99        94          98        5.01
# 5         ushuaia    -54.80     30.20       100          75        8.05
# 8           bluff    -46.60     48.83        94         100       21.70
# ..            ...       ...       ...       ...         ...         ...
# 475          poya    -21.35     69.73        61          89        9.46
# 476   resistencia    -27.46     54.00        87          92        8.05
# 478       manyana    -23.40     47.50        46           0        3.20
# 480  quatre cocos    -20.21     73.99        94          75        9.17
# 481        pangai    -19.80     77.00        88          75       17.22
#
# [159 rows x 6 columns]

# %%
# Perform a linear regression on Northern Hemisphere - Temperature (F) vs. Latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(northern_cities ["Latitude"], northern_cities ["Max Temp"])

# Get regression values
regress_values = northern_cities ["Latitude"] * slope + intercept
# print(regress_values)

# %%
# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)
# Out:
# y = -0.44x +88.98

# %%
# Create Plot
plt.scatter(northern_cities ["Latitude"],northern_cities ["Max Temp"])
plt.plot(northern_cities ["Latitude"],regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="red")

# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-squared is: 0.4246112926768235

# %%
# Perform a linear regression on Southern Hemisphere - Temperature (F) vs. Latitude
(slope, intercept, rvalue, pvalue, stderr) = stats.linregress(southern_cities ["Latitude"], southern_cities ["Max Temp"])

# Get regression values
s_regress_values = southern_cities ["Latitude"] * slope + intercept
# print(regress_values)

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))
print(line_eq)

# Create Plot
plt.scatter(southern_cities ["Latitude"],southern_cities ["Max Temp"])
plt.plot(southern_cities ["Latitude"],s_regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.annotate(line_eq,(20,15),fontsize=15,color="green")

# Print r square value
print(f"The r-squared is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# y = 0.83x +81.76
# The r-squared is: 0.6186022483245907
